# %% [markdown]
# # Self-Driving Car Engineer Nanodegree
#
#
# ## Project: **Finding Lane Lines on the Road**
# ***
# In this project, you will use the tools you learned about in the lesson to identify lane lines on the road.  You can develop your pipeline on a series of individual images, and later apply the result to a video stream (really just a series of images). Check out the video clip "raw-lines-example.mp4" (also contained in this repository) to see what the output should look like after using the helper functions below.
#
# Once you have a result that looks roughly like "raw-lines-example.mp4", you'll need to get creative and try to average and/or extrapolate the line segments you've detected to map out the full extent of the lane lines.  You can see an example of the result you're going for in the video "P1_example.mp4".  Ultimately, you would like to draw just one line for the left side of the lane, and one for the right.
#
# In addition to implementing code, there is a brief writeup to complete. The writeup should be completed in a separate file, which can be either a markdown file or a pdf document. There is a [write up template](https://github.com/udacity/CarND-LaneLines-P1/blob/master/writeup_template.md) that can be used to guide the writing process. Completing both the code in the Ipython notebook and the writeup template will cover all of the [rubric points](https://review.udacity.com/#!/rubrics/322/view) for this project.
#
# ---
# Let's have a look at our first image called 'test_images/solidWhiteRight.jpg'.  Run the 2 cells below (hit Shift-Enter or the "play" button above) to display the image.
#
# **Note: If, at any point, you encounter frozen display windows or other confounding issues, you can always start again with a clean slate by going to the "Kernel" menu above and selecting "Restart & Clear Output".**
#
# ---

# %% [markdown]
# **The tools you have are color selection, region of interest selection, grayscaling, Gaussian smoothing, Canny Edge Detection and Hough Tranform line detection.  You  are also free to explore and try other techniques that were not presented in the lesson.  Your goal is piece together a pipeline to detect the line segments in the image, then average/extrapolate them and draw them onto the image for display (as below).  Once you have a working pipeline, try it out on the video stream below.**
#
# ---
#
# <figure>
#  <img src="examples/line-segments-example.jpg" width="380" alt="Combined Image" />
#  <figcaption>
#  <p></p>
#  <p style="text-align: center;"> Your output should look something like this (above) after detecting line segments using the helper functions below </p>
#  </figcaption>
# </figure>
#  <p></p>
# <figure>
#  <img src="examples/laneLines_thirdPass.jpg" width="380" alt="Combined Image" />
#  <figcaption>
#  <p></p>
#  <p style="text-align: center;"> Your goal is to connect/average/extrapolate line segments to get output like this</p>
#  </figcaption>
# </figure>

# %% [markdown]
# **Run the cell below to import some packages.  If you get an `import error` for a package you've already installed, try changing your kernel (select the Kernel menu above --> Change Kernel).  Still have problems?  Try relaunching Jupyter Notebook from the terminal prompt.  Also, see [this forum post](https://carnd-forums.udacity.com/cq/viewquestion.action?spaceKey=CAR&id=29496372&questionTitle=finding-lanes---import-cv2-fails-even-though-python-in-the-terminal-window-has-no-problem-with-import-cv2) for more troubleshooting tips.**

# %% [markdown]
# ## Import Packages

# %%
#importing some useful packages
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import numpy as np
import cv2
# %matplotlib inline

# %% [markdown]
# ## Read in an Image

# %%
#reading in an image
image = mpimg.imread('test_images/solidWhiteRight.jpg')

#printing out some stats and plotting
print('This image is:', type(image), 'with dimensions:', image.shape)
plt.imshow(image)  # if you wanted to show a single color channel image called 'gray', for example, call as plt.imshow(gray, cmap='gray')
# Out:
# This image is: <class 'numpy.ndarray'> with dimensions: (540, 960, 3)

# %% [markdown]
# ## Ideas for Lane Detection Pipeline

# %% [markdown]
# **Some OpenCV functions (beyond those introduced in the lesson) that might be useful for this project are:**
#
# `cv2.inRange()` for color selection
# `cv2.fillPoly()` for regions selection
# `cv2.line()` to draw lines on an image given endpoints
# `cv2.addWeighted()` to coadd / overlay two images
# `cv2.cvtColor()` to grayscale or change color
# `cv2.imwrite()` to output images to file
# `cv2.bitwise_and()` to apply a mask to an image
#
# **Check out the OpenCV documentation to learn about these and discover even more awesome functionality!**

# %% [markdown]
# ## Helper Functions

# %% [markdown]
# Below are some helper functions to help get you started. They should look familiar from the lesson!

# %%
import math

previousR = []
previousL = []
err_term = 0.5
prevLineR = None
prevLineL = None

def grayscale(img):
    """Applies the Grayscale transform
    This will return an image with only one color channel
    but NOTE: to see the returned image as grayscale
    (assuming your grayscaled image is called 'gray')
    you should call plt.imshow(gray, cmap='gray')"""
    return cv2.cvtColor(img, cv2.COLOR_RGB2GRAY)
    # Or use BGR2GRAY if you read an image with cv2.imread()
    # return cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    
def canny(img, low_threshold, high_threshold):
    """Applies the Canny transform"""
    return cv2.Canny(img, low_threshold, high_threshold)

def gaussian_blur(img, kernel_size):
    """Applies a Gaussian Noise kernel"""
    return cv2.GaussianBlur(img, (kernel_size, kernel_size), 0)

def region_of_interest(img, vertices):
    """
    Applies an image mask.
    
    Only keeps the region of the image defined by the polygon
    formed from `vertices`. The rest of the image is set to black.
    """
    #defining a blank mask to start with
    mask = np.zeros_like(img)   
    
    #defining a 3 channel or 1 channel color to fill the mask with depending on the input image
    if len(img.shape) > 2:
        channel_count = img.shape[2]  # i.e. 3 or 4 depending on your image
        ignore_mask_color = (255,) * channel_count
    else:
        ignore_mask_color = 255
        
    #filling pixels inside the polygon defined by "vertices" with the fill color    
    cv2.fillPoly(mask, vertices, ignore_mask_color)
    
    #returning the image only where mask pixels are nonzero
    masked_image = cv2.bitwise_and(img, mask)
    return masked_image

def get_intersection(line1, line2):
    l1=np.insert(line1, 1, -1)
    l2=np.insert(line2, 1, -1)
    x, y, z= np.cross(l1, l2)
    return np.hstack([x, y]) / z


def create_FitLine(line_hist):
    if (len(line_hist)>0):
        mean = np.array(line_hist).mean(axis=0)
        avg_slope = mean[0]
        avg_intercept = mean[1]
        if (avg_slope<0):
            previousR.append([avg_slope,avg_intercept])
            mean = np.array(previousR).mean(axis=0)
        else:
            previousL.append([avg_slope,avg_intercept])
            mean = np.array(previousL).mean(axis=0)


        global_slope = mean[0]
        global_intercept = mean[1]

        return (global_slope,global_intercept)
    
def disp_fitLine(img,globalLine,intersect,color=[255,0,40],thickness=7):
    
    y1 = img.shape[1]
    y2 = int(intersect[1])
    x1 = int((y1-globalLine[1])/globalLine[0])
    x2 = int((y2-globalLine[1])/globalLine[0])

    cv2.line(img, (x1, y1), (x2, y2), color, thickness)

def draw_lines(img, lines):
    global prevLineR
    global prevLineL
    """
    NOTE: this is the function you might want to use as a starting point once you want to 
    average/extrapolate the line segments you detect to map out the full
    extent of the lane (going from the result shown in raw-lines-example.mp4
    to that shown in P1_example.mp4).  
    
    Think about things like separating line segments by their 
    slope ((y2-y1)/(x2-x1)) to decide which segments are part of the left
    line vs. the right line.  Then, you can average the position of each of 
    the lines and extrapolate to the top and bottom of the lane.
    
    This function draws `lines` with `color` and `thickness`.    
    Lines are drawn on the image inplace (mutates the image).
    If you want to make the lines semi-transparent, think about combining
    this function with the weighted_img() function below
    """
    lineL_hist = []
    lineR_hist = []
    if (len(lines)>0):
        for line in lines:
            bline = np.copy(line)
            
            lShape = bline.shape
            bline = np.reshape(bline,(lShape[0]*2,2))
            vx, vy, x, y = cv2.fitLine(np.array(bline, dtype=np.int32), cv2.DIST_L2, 0, 0.01, 0.01)

            slope = vy/vx
            intercept = y - (slope * x)
            if ((slope < -0.6) and (slope>-0.8)):
                #for x1,y1,x2,y2 in line:
                #    cv2.line(img,(x1,y1),(x2,y2),(255,0,0),10)
                if (len(lineR_hist)==0):
                    lineR_hist.append([slope,intercept])
                else:
                    meanR = np.array(lineR_hist).mean(axis=0)
                    if (abs(slope-meanR[0])<err_term):
                        lineR_hist.append([slope,intercept])
            if ((slope < 0.7) and (slope>0.6) ):
                if (len(lineL_hist)==0):
                    lineL_hist.append([slope,intercept])
                else:
                    meanL = np.array(lineL_hist).mean(axis=0)
                    if (abs(slope-meanL[0])<err_term):
                        lineL_hist.append([slope,intercept])
    else:
        lineR_hist=previousR
        lineL_hist=previousL

    lineR = create_FitLine(lineR_hist)
    lineL = create_FitLine(lineL_hist)
    
    if (lineR is None):
        lineR = prevLineR
    if (lineL is None):
        lineL = prevLineL
    prevLineR = lineR
    prevLineL = lineL
    #print("LineR:",lineR,"PLineR:",prevLineR)
    #print("LineL:",lineL,"PLineL:",prevLineL)
    intersect = get_intersection(lineR,lineL)
    disp_fitLine(img,lineR,intersect)
    disp_fitLine(img,lineL,intersect)
    
    

def hough_lines(img, rho, theta, threshold, min_line_len, max_line_gap):
    """
    `img` should be the output of a Canny transform.
        
    Returns an image with hough lines drawn.
    """
    lines = cv2.HoughLinesP(img, rho, theta, threshold, np.array([]), minLineLength=min_line_len, maxLineGap=max_line_gap)
    line_img = np.zeros((img.shape[0], img.shape[1], 3), dtype=np.uint8)
    draw_lines(line_img, lines)
    return line_img

# Python 3 has support for cool math symbols.

def weighted_img(img, initial_img, α=0.8, β=1., λ=0.):
    """
    `img` is the output of the hough_lines(), An image with lines drawn on it.
    Should be a blank image (all black) with lines drawn on it.
    
    `initial_img` should be the image before any processing.
    
    The result image is computed as follows:
    
    initial_img * α + img * β + λ
    NOTE: initial_img and img must be the same shape!
    """
    return cv2.addWeighted(initial_img, α, img, β, λ)

# %% [markdown]
# ## Test Images
#
# Build your pipeline to work on the images in the directory "test_images"
# **You should make sure your pipeline works well on these images before you try the videos.**

# %%
import os
os.listdir("test_images/")
# Out:
# ['solidWhiteCurve.jpg',
#  'solidWhiteRight.jpg',
#  'solidYellowCurve.jpg',
#  'solidYellowCurve2.jpg',
#  'solidYellowLeft.jpg',
#  'whiteCarLaneSwitch.jpg']

# %%
# Build a Lane Finding Pipeline

# %% [markdown]
# Build the pipeline and run your solution on all test_images. Make copies into the `test_images_output` directory, and you can use the images in your writeup report.
#
# Try tuning the various parameters, especially the low and high Canny thresholds as well as the Hough lines parameters.

# %%
# TODO: Build your pipeline that will draw lane lines on the test_images
# then save them to the test_images directory.
# ============================================================ #
#importing some useful packages
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import numpy as np
import cv2
import os

# ============================================================ # 
def colorInference(image):
    #printing out some stats
    #print(file,' image is:', type(image), 'with dimensions:', image.shape)
    image = cv2.equalizeHist(image)
    ysize = image.shape[0]
    xsize = image.shape[1]
    color_select = np.copy(image)
    line_image = np.copy(image)
    
    # Define color selection criteria
    threshold = 220

    # Mask pixels below the threshold
    color_thresholds = (image[:,:] < threshold)
                    
    # Mask color selection
    color_select[color_thresholds] = 0
    
    return(color_select)

# ============================================================ #  
def houghInference(image):
    
    imshape = image.shape
    gray = grayscale(image)
    gray = colorInference(gray)
    # Gaussian blur with kernel
    kernel_size = 5
    blur_ray = gaussian_blur(gray,kernel_size)
    

    # Define our parameters for Canny and apply
    low_threshold = 50
    high_threshold = 250
    edges = canny(gray, low_threshold, high_threshold)
    
    # Next we'll create a masked edges image using region_of_interest
    vertices = np.array([[  (0,imshape[0]),
                    (430, 315), (510, 315),
                    (imshape[1],imshape[0])
                ]], dtype=np.int32)
    masked_edges = region_of_interest(edges, vertices)
    plt.imshow(masked_edges)
    # Define the Hough transform parameters    
    rho = 2 # distance resolution in pixels of the Hough grid
    theta = np.pi/180 # angular resolution in radians of the Hough grid
    threshold = 10     # minimum number of votes (intersections in Hough grid cell)
    min_line_length = 20 #minimum number of pixels making up a line
    max_line_gap = 10    # maximum gap in pixels between connectable line segments
    line_image = hough_lines(masked_edges, rho, theta, threshold, min_line_length, max_line_gap)
    
    # Create a "color" binary image to combine with line image
    color_edges = np.dstack((masked_edges, masked_edges, masked_edges)) 

    # Draw the lines on the edge image
    lines_edges = weighted_img(line_image, image) 
    #plt.imshow(lines_edges)
    return lines_edges

# ============================================================ #  

file = os.listdir("test_images/")
#reading in an image
image = mpimg.imread('test_images/'+ file[1])
#colorInference(image)
houghInference(image)
# Out:
# LineR: (array([-0.70272821], dtype=float32), array([ 644.38659668], dtype=float32)) PLineR: (array([-0.70272821], dtype=float32), array([ 644.38659668], dtype=float32))
# LineL: (array([ 0.64043564], dtype=float32), array([ 2.12065434], dtype=float32)) PLineL: (array([ 0.64043564], dtype=float32), array([ 2.12065434], dtype=float32))
# array([[[144, 157, 167],
#         [114, 129, 141],
#         [107, 125, 143],
#         ...,
#         [109, 123, 142],
#         [117, 127, 141],
#         [149, 156, 168]],
#
#        [[114, 129, 141],
#         [114, 133, 147],
#         [107, 128, 146],
#         ...,
#         [110, 127, 146],
#         [114, 127, 143],
#         [118, 129, 142]],
#
#        [[105, 126, 143],
#         [106, 129, 146],
#         [102, 127, 150],
#         ...,
#         [103, 125, 148],
#         [109, 126, 146],
#         [107, 122, 141]],
#
#        ...,
#        [[ 96,  97, 100],
#         [ 73,  74,  78],
#         [ 66,  67,  71],
#         ...,
#         [ 70,  71,  74],
#         [ 75,  76,  79],
#         [ 96,  97, 100]],
#
#        [[110, 111, 114],
#         [ 84,  85,  88],
#         [ 71,  72,  76],
#         ...,
#         [ 78,  78,  82],
#         [ 87,  88,  91],
#         [111, 112, 115]],
#
#        [[144, 145, 148],
#         [112, 113, 116],
#         [ 94,  94,  98],
#         ...,
#         [ 98,  98, 100],
#         [112, 113, 114],
#         [143, 144, 146]]], dtype=uint8)

# %% [markdown]
# ## Test on Videos
#
# You know what's cooler than drawing lanes over images? Drawing lanes over video!
#
# We can test our solution on two provided videos:
#
# `solidWhiteRight.mp4`
#
# `solidYellowLeft.mp4`
#
# **Note: if you get an `import error` when you run the next cell, try changing your kernel (select the Kernel menu above --> Change Kernel).  Still have problems?  Try relaunching Jupyter Notebook from the terminal prompt. Also, check out [this forum post](https://carnd-forums.udacity.com/questions/22677062/answers/22677109) for more troubleshooting tips.**
#
# **If you get an error that looks like this:**
# ```
# NeedDownloadError: Need ffmpeg exe.
# You can download it by calling:
# imageio.plugins.ffmpeg.download()
# ```
# **Follow the instructions in the error message and check out [this forum post](https://carnd-forums.udacity.com/display/CAR/questions/26218840/import-videofileclip-error) for more troubleshooting tips across operating systems.**

# %%
# Import everything needed to edit/save/watch video clips
from moviepy.editor import VideoFileClip
from IPython.display import HTML

# %%
def process_image(image):
    # NOTE: The output you return should be a color image (3 channel) for processing video below
    # TODO: put your pipeline here,
    # you should return the final output (image where lines are drawn on lanes)
    result = houghInference(image)

    return result

# %% [markdown]
# Let's try the one with the solid white lane on the right first ...

# %%
white_output = 'test_videos_output/solidWhiteRight.mp4'
clip1 = VideoFileClip('test_videos/solidWhiteRight.mp4')
white_clip = clip1.fl_image(process_image) #NOTE: this function expects color images!!
# %time white_clip.write_videofile(white_output, audio=False)
# Out:
# LineR: (array([-0.71469188], dtype=float32), array([ 648.84375], dtype=float32)) PLineR: (array([-0.71469188], dtype=float32), array([ 648.84375], dtype=float32))
# LineL: (array([ 0.62949216], dtype=float32), array([ 5.96640682], dtype=float32)) PLineL: (array([ 0.62949216], dtype=float32), array([ 5.96640682], dtype=float32))
# [MoviePy] >>>> Building video test_videos_output/solidWhiteRight.mp4
# [MoviePy] Writing video test_videos_output/solidWhiteRight.mp4
#   0%|          | 0/222 [00:00<?, ?it/s]
#
#
#
#
#
#   1%|▏         | 3/222 [00:00<00:08, 27.24it/s]
# LineR: (array([-0.71867973], dtype=float32), array([ 650.32946777], dtype=float32)) PLineR: (array([-0.71867973], dtype=float32), array([ 650.32946777], dtype=float32))
# LineL: (array([ 0.6258443], dtype=float32), array([ 7.24832392], dtype=float32)) PLineL: (array([ 0.6258443], dtype=float32), array([ 7.24832392], dtype=float32))
# LineR: (array([-0.72531593], dtype=float32), array([ 652.01446533], dtype=float32)) PLineR: (array([-0.72531593], dtype=float32), array([ 652.01446533], dtype=float32))
# LineL: (array([ 0.62916005], dtype=float32), array([ 3.7790637], dtype=float32)) PLineL: (array([ 0.62916005], dtype=float32), array([ 3.7790637], dtype=float32))
# LineR: (array([-0.72604221], dtype=float32), array([ 652.53668213], dtype=float32)) PLineR: (array([-0.72604221], dtype=float32), array([ 652.53668213], dtype=float32))
# LineL: (array([ 0.62971735], dtype=float32), array([ 2.90405464], dtype=float32)) PLineL: (array([ 0.62971735], dtype=float32), array([ 2.90405464], dtype=float32))
# LineR: (array([-0.72561055], dtype=float32), array([ 652.46490479], dtype=float32)) PLineR: (array([-0.72561055], dtype=float32), array([ 652.46490479], dtype=float32))
# LineL: (array([ 0.62709671], dtype=float32), array([ 4.60386324], dtype=float32)) PLineL: (array([ 0.62709671], dtype=float32), array([ 4.60386324], dtype=float32))
# LineR: (array([-0.72913176], dtype=float32), array([ 653.70458984], dtype=float32)) PLineR: (array([-0.72913176], dtype=float32), array([ 653.70458984], dtype=float32))
# LineL: (array([ 0.6260699], dtype=float32), array([ 5.08432817], dtype=float32)) PLineL: (array([ 0.6260699], dtype=float32), array([ 5.08432817], dtype=float32))
#   3%|▎         | 6/222 [00:00<00:07, 27.75it/s]
# LineR: (array([-0.72737622], dtype=float32), array([ 652.68206787], dtype=float32)) PLineR: (array([-0.72737622], dtype=float32), array([ 652.68206787], dtype=float32))
# LineL: (array([ 0.62492758], dtype=float32), array([ 5.77956057], dtype=float32)) PLineL: (array([ 0.62492758], dtype=float32), array([ 5.77956057], dtype=float32))
#   5%|▍         | 10/222 [00:00<00:07, 28.28it/s]
# LineR: (array([-0.72377247], dtype=float32), array([ 651.39776611], dtype=float32)) PLineR: (array([-0.72377247], dtype=float32), array([ 651.39776611], dtype=float32))
# LineL: (array([ 0.62373281], dtype=float32), array([ 6.28194618], dtype=float32)) PLineL: (array([ 0.62373281], dtype=float32), array([ 6.28194618], dtype=float32))
# LineR: (array([-0.72536677], dtype=float32), array([ 651.86126709], dtype=float32)) PLineR: (array([-0.72536677], dtype=float32), array([ 651.86126709], dtype=float32))
# LineL: (array([ 0.62358385], dtype=float32), array([ 6.16030693], dtype=float32)) PLineL: (array([ 0.62358385], dtype=float32), array([ 6.16030693], dtype=float32))
# LineR: (array([-0.72529739], dtype=float32), array([ 651.78466797], dtype=float32)) PLineR: (array([-0.72529739], dtype=float32), array([ 651.78466797], dtype=float32))
# LineL: (array([ 0.62417966], dtype=float32), array([ 5.40957212], dtype=float32)) PLineL: (array([ 0.62417966], dtype=float32), array([ 5.40957212], dtype=float32))
# LineR: (array([-0.72613484], dtype=float32), array([ 652.16888428], dtype=float32)) PLineR: (array([-0.72613484], dtype=float32), array([ 652.16888428], dtype=float32))
# LineL: (array([ 0.62578744], dtype=float32), array([ 4.63683462], dtype=float32)) PLineL: (array([ 0.62578744], dtype=float32), array([ 4.63683462], dtype=float32))
# LineR: (array([-0.72553909], dtype=float32), array([ 652.14117432], dtype=float32)) PLineR: (array([-0.72553909], dtype=float32), array([ 652.14117432], dtype=float32))
# LineL: (array([ 0.62736446], dtype=float32), array([ 3.78671598], dtype=float32)) PLineL: (array([ 0.62736446], dtype=float32), array([ 3.78671598], dtype=float32))
# LineR:
#  (array([-0.72607231], dtype=float32), array([ 652.49304199], dtype=float32)) PLineR: (array([-0.72607231], dtype=float32), array([ 652.49304199], dtype=float32))
# LineL: (array([ 0.62890786], dtype=float32), array([ 3.28871727], dtype=float32)) PLineL: (array([ 0.62890786], dtype=float32), array([ 3.28871727], dtype=float32))
#   6%|▌         | 13/222 [00:00<00:07, 28.32it/s]
#
#
#
#
#
#   7%|▋         | 16/222 [00:00<00:07, 28.51it/s]
# LineR: (array([-0.72602844], dtype=float32), array([ 652.78619385], dtype=float32)) PLineR: (array([-0.72602844], dtype=float32), array([ 652.78619385], dtype=float32))
# LineL: (array([ 0.62913245], dtype=float32), array([ 3.38362098], dtype=float32)) PLineL: (array([ 0.62913245], dtype=float32), array([ 3.38362098], dtype=float32))
# LineR: (array([-0.72533262], dtype=float32), array([ 652.49963379], dtype=float32)) PLineR: (array([-0.72533262], dtype=float32), array([ 652.49963379], dtype=float32))
# LineL: (array([ 0.62964183], dtype=float32), array([ 3.17322373], dtype=float32)) PLineL: (array([ 0.62964183], dtype=float32), array([ 3.17322373], dtype=float32))
# LineR: (array([-0.72505087], dtype=float32), array([ 652.32928467], dtype=float32)) PLineR: (array([-0.72505087], dtype=float32), array([ 652.32928467], dtype=float32))
# LineL: (array([ 0.63012815], dtype=float32), array([ 3.01876283], dtype=float32)) PLineL: (array([ 0.63012815], dtype=float32), array([ 3.01876283], dtype=float32))
# LineR: (array([-0.72416282], dtype=float32), array([ 651.7512207], dtype=float32)) PLineR: (array([-0.72416282], dtype=float32), array([ 651.7512207], dtype=float32))
# LineL: (array([ 0.63024777], dtype=float32), array([ 3.03178096], dtype=float32)) PLineL: (array([ 0.63024777], dtype=float32), array([ 3.03178096], dtype=float32))
# LineR: (array([-0.72410387], dtype=float32), array([ 651.47174072], dtype=float32)) PLineR: (array([-0.72410387], dtype=float32), array([ 651.47174072], dtype=float32))
# LineL: (array([ 0.63048172], dtype=float32), array([ 2.94582415], dtype=float32)) PLineL: (array([ 0.63048172], dtype=float32), array([ 2.94582415], dtype=float32))
# LineR: (array([-0.72271574], dtype=float32), array([ 650.74786377], dtype=float32)) PLineR: (array([-0.72271574], dtype=float32), array([ 650.74786377], dtype=float32))
# LineL: (array([ 0.63138491], dtype=float32), array([ 2.37088609], dtype=float32)) PLineL: (array([ 0.63138491], dtype=float32), array([ 2.37088609], dtype=float32))
# LineR:
#   9%|▉         | 20/222 [00:00<00:06, 29.01it/s]
#
#
#
#
#
#  11%|█         | 24/222 [00:00<00:06, 29.58it/s]
#  (array([-0.72107726], dtype=float32), array([ 650.02923584], dtype=float32)) PLineR: (array([-0.72107726], dtype=float32), array([ 650.02923584], dtype=float32))
# LineL: (array([ 0.63175923], dtype=float32), array([ 2.23875713], dtype=float32)) PLineL: (array([ 0.63175923], dtype=float32), array([ 2.23875713], dtype=float32))
# LineR: (array([-0.7198689], dtype=float32), array([ 649.61395264], dtype=float32)) PLineR: (array([-0.7198689], dtype=float32), array([ 649.61395264], dtype=float32))
# LineL: (array([ 0.63227135], dtype=float32), array([ 2.04029036], dtype=float32)) PLineL: (array([ 0.63227135], dtype=float32), array([ 2.04029036], dtype=float32))
# LineR: (array([-0.71865505], dtype=float32), array([ 649.25372314], dtype=float32)) PLineR: (array([-0.71865505], dtype=float32), array([ 649.25372314], dtype=float32))
# LineL: (array([ 0.63247472], dtype=float32), array([ 2.11081195], dtype=float32)) PLineL: (array([ 0.63247472], dtype=float32), array([ 2.11081195], dtype=float32))
# LineR: (array([-0.71713257], dtype=float32), array([ 648.79547119], dtype=float32)) PLineR: (array([-0.71713257], dtype=float32), array([ 648.79547119], dtype=float32))
# LineL: (array([ 0.63285893], dtype=float32), array([ 1.89267957], dtype=float32)) PLineL: (array([ 0.63285893], dtype=float32), array([ 1.89267957], dtype=float32))
# LineR: (array([-0.71675652], dtype=float32), array([ 648.7567749], dtype=float32)) PLineR: (array([-0.71675652], dtype=float32), array([ 648.7567749], dtype=float32))
# LineL: (array([ 0.63304192], dtype=float32), array([ 1.86787748], dtype=float32)) PLineL: (array([ 0.63304192], dtype=float32), array([ 1.86787748], dtype=float32))
# LineR: (array([-0.71691805], dtype=float32), array([ 648.8526001], dtype=float32)) PLineR: (array([-0.71691805], dtype=float32), array([ 648.8526001], dtype=float32))
# LineL: (array([ 0.63390881], dtype=float32), array([ 1.28376603], dtype=float32)) PLineL: (array([ 0.63390881], dtype=float32), array([ 1.28376603], dtype=float32))
# LineR: (array([-0.71642298], dtype=float32), array([ 648.7243042], dtype=float32)) PLineR: (array([-0.71642298], dtype=float32), array([ 648.7243042], dtype=float32))
# LineL: (array([ 0.63411641], dtype=float32), array([ 1.23877847], dtype=float32)) PLineL:
#  12%|█▏        | 27/222 [00:00<00:06, 29.25it/s]
#
#
#
#
#
#  14%|█▎        | 30/222 [00:01<00:06, 28.95it/s]
# (array([ 0.63411641], dtype=float32), array([ 1.23877847], dtype=float32))
# LineR: (array([-0.71685272], dtype=float32), array([ 648.85125732], dtype=float32)) PLineR: (array([-0.71685272], dtype=float32), array([ 648.85125732], dtype=float32))
# LineL: (array([ 0.63412106], dtype=float32), array([ 1.30496132], dtype=float32)) PLineL: (array([ 0.63412106], dtype=float32), array([ 1.30496132], dtype=float32))
# LineR: (array([-0.71689647], dtype=float32), array([ 648.92987061], dtype=float32)) PLineR: (array([-0.71689647], dtype=float32), array([ 648.92987061], dtype=float32))
# LineL: (array([ 0.63410711], dtype=float32), array([ 1.28846002], dtype=float32)) PLineL: (array([ 0.63410711], dtype=float32), array([ 1.28846002], dtype=float32))
# LineR: (array([-0.7164042], dtype=float32), array([ 648.82330322], dtype=float32)) PLineR: (array([-0.7164042], dtype=float32), array([ 648.82330322], dtype=float32))
# LineL: (array([ 0.63456053], dtype=float32), array([ 1.04486763], dtype=float32)) PLineL: (array([ 0.63456053], dtype=float32), array([ 1.04486763], dtype=float32))
# LineR: (array([-0.71675479], dtype=float32), array([ 648.92578125], dtype=float32)) PLineR: (array([-0.71675479], dtype=float32), array([ 648.92578125], dtype=float32))
# LineL: (array([ 0.63519609], dtype=float32), array([ 0.69552463], dtype=float32)) PLineL: (array([ 0.63519609], dtype=float32), array([ 0.69552463], dtype=float32))
# LineR: (array([-0.71700859], dtype=float32), array([ 649.0324707], dtype=float32)) PLineR: (array([-0.71700859], dtype=float32), array([ 649.0324707], dtype=float32))
# LineL: (array([ 0.63527107], dtype=float32), array([ 0.71908849], dtype=float32)) PLineL: (array([ 0.63527107], dtype=float32), array([ 0.71908849], dtype=float32))
# LineR: (array([-0.71772188], dtype=float32), array([ 649.28753662], dtype=float32)) PLineR: (array([-0.71772188], dtype=float32), array([ 649.28753662], dtype=float32))
# LineL: (array([ 0.63545352], dtype=float32), array([ 0.60549766], dtype=float32)) PLineL: (array([ 0.63545352], dtype=float32), array([ 0.60549766], dtype=float32))
#  15%|█▍        | 33/222 [00:01<00:06, 28.94it/s]
# LineR: (array([-0.71745712], dtype=float32), array([ 649.17993164], dtype=float32)) PLineR: (array([-0.71745712], dtype=float32), array([ 649.17993164], dtype=float32))
# LineL: (array([ 0.63553399], dtype=float32), array([ 0.53380698], dtype=float32)) PLineL: (array([ 0.63553399], dtype=float32), array([ 0.53380698], dtype=float32))
# LineR: (array([-0.71780866], dtype=float32), array([ 649.27941895], dtype=float32)) PLineR: (array([-0.71780866], dtype=float32), array([ 649.27941895], dtype=float32))
# LineL: (array([ 0.63548958], dtype=float32), array([ 0.50219822], dtype=float32)) PLineL: (array([ 0.63548958], dtype=float32), array([ 0.50219822], dtype=float32))
# LineR: (array([-0.71794534], dtype=float32), array([ 649.33721924], dtype=float32)) PLineR: (array([-0.71794534], dtype=float32), array([ 649.33721924], dtype=float32))
# LineL: (array([ 0.63538051], dtype=float32), array([ 0.60155845], dtype=float32)) PLineL: (array([ 0.63538051], dtype=float32), array([ 0.60155845], dtype=float32))
# LineR: (array([-0.71804744], dtype=float32), array([ 649.41015625], dtype=float32)) PLineR: (array([-0.71804744], dtype=float32), array([ 649.41015625], dtype=float32))
# LineL: (array([ 0.63533342], dtype=float32), array([ 0.59723485], dtype=float32)) PLineL: (array([ 0.63533342], dtype=float32), array([ 0.59723485], dtype=float32))
# LineR: (array([-0.71777731], dtype=float32), array([ 649.34857178], dtype=float32)) PLineR: (array([-0.71777731], dtype=float32), array([ 649.34857178], dtype=float32))
# LineL: (array([ 0.63528997], dtype=float32), array([ 0.70370531], dtype=float32)) PLineL: (array([ 0.63528997], dtype=float32), array([ 0.70370531], dtype=float32))
# LineR:
#  17%|█▋        | 37/222 [00:01<00:06, 29.04it/s]
#  (array([-0.71713471], dtype=float32), array([ 649.21942139], dtype=float32)) PLineR: (array([-0.71713471], dtype=float32), array([ 649.21942139], dtype=float32))
# LineL: (array([ 0.63511616], dtype=float32), array([ 0.86324269], dtype=float32)) PLineL: (array([ 0.63511616], dtype=float32), array([ 0.86324269], dtype=float32))
#  18%|█▊        | 40/222 [00:01<00:06, 28.83it/s]
# LineR: (array([-0.71750438], dtype=float32), array([ 649.36682129], dtype=float32)) PLineR: (array([-0.71750438], dtype=float32), array([ 649.36682129], dtype=float32))
# LineL: (array([ 0.63542372], dtype=float32), array([ 0.73594582], dtype=float32)) PLineL: (array([ 0.63542372], dtype=float32), array([ 0.73594582], dtype=float32))
# LineR: (array([-0.71779472], dtype=float32), array([ 649.47570801], dtype=float32)) PLineR: (array([-0.71779472], dtype=float32), array([ 649.47570801], dtype=float32))
# LineL: (array([ 0.63533455], dtype=float32), array([ 0.77362216], dtype=float32)) PLineL: (array([ 0.63533455], dtype=float32), array([ 0.77362216], dtype=float32))
# LineR: (array([-0.71763986], dtype=float32), array([ 649.48504639], dtype=float32)) PLineR: (array([-0.71763986], dtype=float32), array([ 649.48504639], dtype=float32))
# LineL: (array([ 0.63550121], dtype=float32), array([ 0.71293521], dtype=float32)) PLineL: (array([ 0.63550121], dtype=float32), array([ 0.71293521], dtype=float32))
# LineR: (array([-0.71739578], dtype=float32), array([ 649.30072021], dtype=float32)) PLineR: (array([-0.71739578], dtype=float32), array([ 649.30072021], dtype=float32))
# LineL: (array([ 0.6356675], dtype=float32), array([ 0.60376436], dtype=float32)) PLineL: (array([ 0.6356675], dtype=float32), array([ 0.60376436], dtype=float32))
# LineR: (array([-0.71697128], dtype=float32), array([ 649.1161499], dtype=float32)) PLineR: (array([-0.71697128], dtype=float32), array([ 649.1161499], dtype=float32))
# LineL: (array([ 0.63621372], dtype=float32), array([ 0.20373279], dtype=float32)) PLineL: (array([ 0.63621372], dtype=float32), array([ 0.20373279], dtype=float32))
#  19%|█▉        | 43/222 [00:01<00:06, 28.92it/s]
# LineR: (array([-0.71745408], dtype=float32), array([ 649.25891113], dtype=float32)) PLineR: (array([-0.71745408], dtype=float32), array([ 649.25891113], dtype=float32))
# LineL: (array([ 0.63628042], dtype=float32), array([ 0.17703938], dtype=float32)) PLineL: (array([ 0.63628042], dtype=float32), array([ 0.17703938], dtype=float32))
#  21%|██        | 46/222 [00:01<00:06, 28.26it/s]
# LineR: (array([-0.71799964], dtype=float32), array([ 649.42907715], dtype=float32)) PLineR: (array([-0.71799964], dtype=float32), array([ 649.42907715], dtype=float32))
# LineL: (array([ 0.63636267], dtype=float32), array([ 0.11009587], dtype=float32)) PLineL: (array([ 0.63636267], dtype=float32), array([ 0.11009587], dtype=float32))
# LineR: (array([-0.71809977], dtype=float32), array([ 649.355896], dtype=float32)) PLineR: (array([-0.71809977], dtype=float32), array([ 649.355896], dtype=float32))
# LineL: (array([ 0.63680321], dtype=float32), array([-0.24223167], dtype=float32)) PLineL: (array([ 0.63680321], dtype=float32), array([-0.24223167], dtype=float32))
# LineR: (array([-0.71826643], dtype=float32), array([ 649.35351562], dtype=float32)) PLineR: (array([-0.71826643], dtype=float32), array([ 649.35351562], dtype=float32))
# LineL: (array([ 0.63724655], dtype=float32), array([-0.51653391], dtype=float32)) PLineL: (array([ 0.63724655], dtype=float32), array([-0.51653391], dtype=float32))
# LineR: (array([-0.71864498], dtype=float32), array([ 649.44140625], dtype=float32)) PLineR: (array([-0.71864498], dtype=float32), array([ 649.44140625], dtype=float32))
# LineL: (array([ 0.63744903], dtype=float32), array([-0.67542362], dtype=float32)) PLineL: (array([ 0.63744903], dtype=float32), array([-0.67542362], dtype=float32))
# LineR: (array([-0.71881098], dtype=float32), array([ 649.46130371], dtype=float32)) PLineR: (array([-0.71881098], dtype=float32), array([ 649.46130371], dtype=float32))
# LineL: (array([ 0.63808256], dtype=float32), array([-1.10493875], dtype=float32)) PLineL: (array([ 0.63808256], dtype=float32), array([-1.10493875], dtype=float32))
#  22%|██▏       | 49/222 [00:01<00:06, 28.37it/s]
# LineR: (array([-0.71916324], dtype=float32), array([ 649.53546143], dtype=float32)) PLineR: (array([-0.71916324], dtype=float32), array([ 649.53546143], dtype=float32))
# LineL: (array([ 0.63827872], dtype=float32), array([-1.32301116], dtype=float32)) PLineL: (array([ 0.63827872], dtype=float32), array([-1.32301116], dtype=float32))
#  23%|██▎       | 52/222 [00:01<00:06, 27.83it/s]
# LineR: (array([-0.71967548], dtype=float32), array([ 649.64459229], dtype=float32)) PLineR: (array([-0.71967548], dtype=float32), array([ 649.64459229], dtype=float32))
# LineL: (array([ 0.63878131], dtype=float32), array([-1.7003814], dtype=float32)) PLineL: (array([ 0.63878131], dtype=float32), array([-1.7003814], dtype=float32))
# LineR: (array([-0.71995848], dtype=float32), array([ 649.64013672], dtype=float32)) PLineR: (array([-0.71995848], dtype=float32), array([ 649.64013672], dtype=float32))
# LineL: (array([ 0.63921565], dtype=float32), array([-1.99206686], dtype=float32)) PLineL: (array([ 0.63921565], dtype=float32), array([-1.99206686], dtype=float32))
# LineR: (array([-0.71976942], dtype=float32), array([ 649.48358154], dtype=float32)) PLineR: (array([-0.71976942], dtype=float32), array([ 649.48358154], dtype=float32))
# LineL: (array([ 0.63963586], dtype=float32), array([-2.3356998], dtype=float32)) PLineL: (array([ 0.63963586], dtype=float32), array([-2.3356998], dtype=float32))
# LineR: (array([-0.71982992], dtype=float32), array([ 649.38745117], dtype=float32)) PLineR: (array([-0.71982992], dtype=float32), array([ 649.38745117], dtype=float32))
# LineL: (array([ 0.63952619], dtype=float32), array([-2.28309703], dtype=float32)) PLineL: (array([ 0.63952619], dtype=float32), array([-2.28309703], dtype=float32))
# LineR: (array([-0.720074], dtype=float32), array([ 649.39898682], dtype=float32)) PLineR: (array([-0.720074], dtype=float32), array([ 649.39898682], dtype=float32))
# LineL: (array([ 0.63997567], dtype=float32), array([-2.6221683], dtype=float32)) PLineL: (array([ 0.63997567], dtype=float32), array([-2.6221683], dtype=float32))
#  25%|██▍       | 55/222 [00:01<00:06, 27.06it/s]
# LineR: (array([-0.7198168], dtype=float32), array([ 649.23095703], dtype=float32)) PLineR: (array([-0.7198168], dtype=float32), array([ 649.23095703], dtype=float32))
# LineL: (array([ 0.64024228], dtype=float32), array([-2.81347156], dtype=float32)) PLineL: (array([ 0.64024228], dtype=float32), array([-2.81347156], dtype=float32))
#  26%|██▌       | 58/222 [00:02<00:06, 26.56it/s]
# LineR: (array([-0.71958405], dtype=float32), array([ 649.0980835], dtype=float32)) PLineR: (array([-0.71958405], dtype=float32), array([ 649.0980835], dtype=float32))
# LineL: (array([ 0.64015889], dtype=float32), array([-2.70756269], dtype=float32)) PLineL: (array([ 0.64015889], dtype=float32), array([-2.70756269], dtype=float32))
# LineR: (array([-0.71906447], dtype=float32), array([ 648.88824463], dtype=float32)) PLineR: (array([-0.71906447], dtype=float32), array([ 648.88824463], dtype=float32))
# LineL: (array([ 0.64021909], dtype=float32), array([-2.7071979], dtype=float32)) PLineL: (array([ 0.64021909], dtype=float32), array([-2.7071979], dtype=float32))
# LineR: (array([-0.71837455], dtype=float32), array([ 648.61853027], dtype=float32)) PLineR: (array([-0.71837455], dtype=float32), array([ 648.61853027], dtype=float32))
# LineL: (array([ 0.64017552], dtype=float32), array([-2.60087967], dtype=float32)) PLineL: (array([ 0.64017552], dtype=float32), array([-2.60087967], dtype=float32))
# LineR: (array([-0.71765602], dtype=float32), array([ 648.32830811], dtype=float32)) PLineR: (array([-0.71765602], dtype=float32), array([ 648.32830811], dtype=float32))
# LineL: (array([ 0.64015073], dtype=float32), array([-2.52513337], dtype=float32)) PLineL: (array([ 0.64015073], dtype=float32), array([-2.52513337], dtype=float32))
# LineR: (array([-0.71760863], dtype=float32), array([ 648.26898193], dtype=float32)) PLineR: (array([-0.71760863], dtype=float32), array([ 648.26898193], dtype=float32))
# LineL: (array([ 0.64017045], dtype=float32), array([-2.44143724], dtype=float32)) PLineL: (array([ 0.64017045], dtype=float32), array([-2.44143724], dtype=float32))
# LineR: (array([-0.71724987], dtype=float32), array([ 648.08905029], dtype=float32)) PLineR: (array([-0.71724987], dtype=float32), array([ 648.08905029], dtype=float32))
# LineL: (array([ 0.64065784], dtype=float32), array([-2.75144458], dtype=float32))
#  27%|██▋       | 61/222 [00:02<00:06, 26.06it/s]
#
#
#
#
#
#  29%|██▉       | 64/222 [00:02<00:05, 26.36it/s]
#  PLineL: (array([ 0.64065784], dtype=float32), array([-2.75144458], dtype=float32))
# LineR: (array([-0.71676356], dtype=float32), array([ 647.85882568], dtype=float32)) PLineR: (array([-0.71676356], dtype=float32), array([ 647.85882568], dtype=float32))
# LineL: (array([ 0.64059544], dtype=float32), array([-2.65435505], dtype=float32)) PLineL: (array([ 0.64059544], dtype=float32), array([-2.65435505], dtype=float32))
# LineR: (array([-0.7163015], dtype=float32), array([ 647.65722656], dtype=float32)) PLineR: (array([-0.7163015], dtype=float32), array([ 647.65722656], dtype=float32))
# LineL: (array([ 0.64089364], dtype=float32), array([-2.82913351], dtype=float32)) PLineL: (array([ 0.64089364], dtype=float32), array([-2.82913351], dtype=float32))
# LineR: (array([-0.71544468], dtype=float32), array([ 647.340271], dtype=float32)) PLineR: (array([-0.71544468], dtype=float32), array([ 647.340271], dtype=float32))
# LineL: (array([ 0.64103949], dtype=float32), array([-2.84954691], dtype=float32)) PLineL: (array([ 0.64103949], dtype=float32), array([-2.84954691], dtype=float32))
# LineR: (array([-0.71477944], dtype=float32), array([ 647.06121826], dtype=float32)) PLineR: (array([-0.71477944], dtype=float32), array([ 647.06121826], dtype=float32))
# LineL: (array([ 0.64141846], dtype=float32), array([-3.02945304], dtype=float32)) PLineL: (array([ 0.64141846], dtype=float32), array([-3.02945304], dtype=float32))
# LineR: (array([-0.71415991], dtype=float32), array([ 646.79882812], dtype=float32)) PLineR: (array([-0.71415991], dtype=float32), array([ 646.79882812], dtype=float32))
# LineL: (array([ 0.64165568], dtype=float32), array([-3.14496493], dtype=float32)) PLineL: (array([ 0.64165568], dtype=float32), array([-3.14496493], dtype=float32))
#  30%|███       | 67/222 [00:02<00:05, 26.72it/s]
# LineR: (array([-0.71360904], dtype=float32), array([ 646.53363037], dtype=float32)) PLineR: (array([-0.71360904], dtype=float32), array([ 646.53363037], dtype=float32))
# LineL: (array([ 0.64188987], dtype=float32), array([-3.25930333], dtype=float32)) PLineL: (array([ 0.64188987], dtype=float32), array([-3.25930333], dtype=float32))
#  32%|███▏      | 70/222 [00:02<00:05, 26.24it/s]
# LineR: (array([-0.71284169], dtype=float32), array([ 646.18353271], dtype=float32)) PLineR: (array([-0.71284169], dtype=float32), array([ 646.18353271], dtype=float32))
# LineL: (array([ 0.64216423], dtype=float32), array([-3.41509891], dtype=float32)) PLineL: (array([ 0.64216423], dtype=float32), array([-3.41509891], dtype=float32))
# LineR: (array([-0.71199721], dtype=float32), array([ 645.82714844], dtype=float32)) PLineR: (array([-0.71199721], dtype=float32), array([ 645.82714844], dtype=float32))
# LineL: (array([ 0.64236951], dtype=float32), array([-3.53165936], dtype=float32)) PLineL: (array([ 0.64236951], dtype=float32), array([-3.53165936], dtype=float32))
# LineR: (array([-0.71159714], dtype=float32), array([ 645.62506104], dtype=float32)) PLineR: (array([-0.71159714], dtype=float32), array([ 645.62506104], dtype=float32))
# LineL: (array([ 0.64234155], dtype=float32), array([-3.46029067], dtype=float32)) PLineL: (array([ 0.64234155], dtype=float32), array([-3.46029067], dtype=float32))
# LineR: (array([-0.71119052], dtype=float32), array([ 645.42529297], dtype=float32)) PLineR: (array([-0.71119052], dtype=float32), array([ 645.42529297], dtype=float32))
# LineL: (array([ 0.64268279], dtype=float32), array([-3.67198539], dtype=float32)) PLineL: (array([ 0.64268279], dtype=float32), array([-3.67198539], dtype=float32))
# LineR: (array([-0.71106011], dtype=float32), array([ 645.29956055], dtype=float32)) PLineR: (array([-0.71106011], dtype=float32), array([ 645.29956055], dtype=float32))
# LineL: (array([ 0.64304996], dtype=float32), array([-3.90726852], dtype=float32)) PLineL: (array([ 0.64304996], dtype=float32), array([-3.90726852], dtype=float32))
#  33%|███▎      | 73/222 [00:02<00:05, 26.32it/s]
# LineR: (array([-0.71023977], dtype=float32), array([ 644.99066162], dtype=float32)) PLineR: (array([-0.71023977], dtype=float32), array([ 644.99066162], dtype=float32))
# LineL: (array([ 0.64345437], dtype=float32), array([-4.1657691], dtype=float32)) PLineL: (array([ 0.64345437], dtype=float32), array([-4.1657691], dtype=float32))
#  34%|███▍      | 76/222 [00:02<00:05, 26.66it/s]
# LineR: (array([-0.70964122], dtype=float32), array([ 644.72241211], dtype=float32)) PLineR: (array([-0.70964122], dtype=float32), array([ 644.72241211], dtype=float32))
# LineL: (array([ 0.64355814], dtype=float32), array([-4.15924597], dtype=float32)) PLineL: (array([ 0.64355814], dtype=float32), array([-4.15924597], dtype=float32))
# LineR: (array([-0.70918733], dtype=float32), array([ 644.51739502], dtype=float32)) PLineR: (array([-0.70918733], dtype=float32), array([ 644.51739502], dtype=float32))
# LineL: (array([ 0.64378667], dtype=float32), array([-4.26270247], dtype=float32)) PLineL: (array([ 0.64378667], dtype=float32), array([-4.26270247], dtype=float32))
# LineR: (array([-0.70861137], dtype=float32), array([ 644.2388916], dtype=float32)) PLineR: (array([-0.70861137], dtype=float32), array([ 644.2388916], dtype=float32))
# LineL: (array([ 0.64402348], dtype=float32), array([-4.38132238], dtype=float32)) PLineL: (array([ 0.64402348], dtype=float32), array([-4.38132238], dtype=float32))
# LineR: (array([-0.70808369], dtype=float32), array([ 643.99346924], dtype=float32)) PLineR: (array([-0.70808369], dtype=float32), array([ 643.99346924], dtype=float32))
# LineL: (array([ 0.64406013], dtype=float32), array([-4.34054947], dtype=float32)) PLineL: (array([ 0.64406013], dtype=float32), array([-4.34054947], dtype=float32))
# LineR: (array([-0.70725352], dtype=float32), array([ 643.62518311], dtype=float32)) PLineR: (array([-0.70725352], dtype=float32), array([ 643.62518311], dtype=float32))
# LineL: (array([ 0.64424646], dtype=float32), array([-4.35234261], dtype=float32)) PLineL: (array([ 0.64424646], dtype=float32), array([-4.35234261], dtype=float32))
#  36%|███▌      | 79/222 [00:02<00:05, 26.78it/s]
# LineR: (array([-0.70714533], dtype=float32), array([ 643.51416016], dtype=float32)) PLineR: (array([-0.70714533], dtype=float32), array([ 643.51416016], dtype=float32))
# LineL: (array([ 0.64468354], dtype=float32), array([-4.56472921], dtype=float32)) PLineL: (array([ 0.64468354], dtype=float32), array([-4.56472921], dtype=float32))
#  37%|███▋      | 82/222 [00:02<00:05, 26.54it/s]
# LineR: (array([-0.70664924], dtype=float32), array([ 643.27593994], dtype=float32)) PLineR: (array([-0.70664924], dtype=float32), array([ 643.27593994], dtype=float32))
# LineL: (array([ 0.64493191], dtype=float32), array([-4.61541843], dtype=float32)) PLineL: (array([ 0.64493191], dtype=float32), array([-4.61541843], dtype=float32))
# LineR: (array([-0.70601773], dtype=float32), array([ 642.97851562], dtype=float32)) PLineR: (array([-0.70601773], dtype=float32), array([ 642.97851562], dtype=float32))
# LineL: (array([ 0.64525729], dtype=float32), array([-4.79449368], dtype=float32)) PLineL: (array([ 0.64525729], dtype=float32), array([-4.79449368], dtype=float32))
# LineR: (array([-0.70541435], dtype=float32), array([ 642.69616699], dtype=float32)) PLineR: (array([-0.70541435], dtype=float32), array([ 642.69616699], dtype=float32))
# LineL: (array([ 0.64569598], dtype=float32), array([-5.03286076], dtype=float32)) PLineL: (array([ 0.64569598], dtype=float32), array([-5.03286076], dtype=float32))
# LineR: (array([-0.70499158], dtype=float32), array([ 642.4855957], dtype=float32)) PLineR: (array([-0.70499158], dtype=float32), array([ 642.4855957], dtype=float32))
# LineL: (array([ 0.64578623], dtype=float32), array([-5.05454493], dtype=float32)) PLineL: (array([ 0.64578623], dtype=float32), array([-5.05454493], dtype=float32))
# LineR: (array([-0.70460051], dtype=float32), array([ 642.28240967], dtype=float32)) PLineR: (array([-0.70460051], dtype=float32), array([ 642.28240967], dtype=float32))
# LineL: (array([ 0.646137], dtype=float32), array([-5.24403048], dtype=float32)) PLineL: (array([ 0.646137], dtype=float32), array([-5.24403048], dtype=float32))
#  38%|███▊      | 85/222 [00:03<00:05, 26.47it/s]
# LineR: (array([-0.70395488], dtype=float32), array([ 642.01165771], dtype=float32)) PLineR: (array([-0.70395488], dtype=float32), array([ 642.01165771], dtype=float32))
# LineL: (array([ 0.64648068], dtype=float32), array([-5.45391083], dtype=float32)) PLineL: (array([ 0.64648068], dtype=float32), array([-5.45391083], dtype=float32))
#  40%|███▉      | 88/222 [00:03<00:04, 26.94it/s]
# LineR: (array([-0.70374864], dtype=float32), array([ 641.85583496], dtype=float32)) PLineR: (array([-0.70374864], dtype=float32), array([ 641.85583496], dtype=float32))
# LineL: (array([ 0.64649737], dtype=float32), array([-5.42043686], dtype=float32)) PLineL: (array([ 0.64649737], dtype=float32), array([-5.42043686], dtype=float32))
# LineR: (array([-0.70325446], dtype=float32), array([ 641.61791992], dtype=float32)) PLineR: (array([-0.70325446], dtype=float32), array([ 641.61791992], dtype=float32))
# LineL: (array([ 0.64690083], dtype=float32), array([-5.62939262], dtype=float32)) PLineL: (array([ 0.64690083], dtype=float32), array([-5.62939262], dtype=float32))
# LineR: (array([-0.70260084], dtype=float32), array([ 641.35241699], dtype=float32)) PLineR: (array([-0.70260084], dtype=float32), array([ 641.35241699], dtype=float32))
# LineL: (array([ 0.64696115], dtype=float32), array([-5.65013647], dtype=float32)) PLineL: (array([ 0.64696115], dtype=float32), array([-5.65013647], dtype=float32))
# LineR: (array([-0.70233911], dtype=float32), array([ 641.2052002], dtype=float32)) PLineR: (array([-0.70233911], dtype=float32), array([ 641.2052002], dtype=float32))
# LineL: (array([ 0.64742815], dtype=float32), array([-5.8760457], dtype=float32)) PLineL: (array([ 0.64742815], dtype=float32), array([-5.8760457], dtype=float32))
# LineR: (array([-0.70186746], dtype=float32), array([ 640.99517822], dtype=float32)) PLineR: (array([-0.70186746], dtype=float32), array([ 640.99517822], dtype=float32))
# LineL: (array([ 0.6477893], dtype=float32), array([-6.01561594], dtype=float32)) PLineL: (array([ 0.6477893], dtype=float32), array([-6.01561594], dtype=float32))
#  41%|████      | 91/222 [00:03<00:04, 26.64it/s]
# LineR: (array([-0.70146918], dtype=float32), array([ 640.82415771], dtype=float32)) PLineR: (array([-0.70146918], dtype=float32), array([ 640.82415771], dtype=float32))
# LineL: (array([ 0.64807469], dtype=float32), array([-6.13926792], dtype=float32)) PLineL: (array([ 0.64807469], dtype=float32), array([-6.13926792], dtype=float32))
#  42%|████▏     | 94/222 [00:03<00:04, 27.26it/s]
# LineR: (array([-0.7010507], dtype=float32), array([ 640.65997314], dtype=float32)) PLineR: (array([-0.7010507], dtype=float32), array([ 640.65997314], dtype=float32))
# LineL: (array([ 0.64842099], dtype=float32), array([-6.28629494], dtype=float32)) PLineL: (array([ 0.64842099], dtype=float32), array([-6.28629494], dtype=float32))
# LineR: (array([-0.7005499], dtype=float32), array([ 640.45898438], dtype=float32)) PLineR: (array([-0.7005499], dtype=float32), array([ 640.45898438], dtype=float32))
# LineL: (array([ 0.64883864], dtype=float32), array([-6.49362993], dtype=float32)) PLineL: (array([ 0.64883864], dtype=float32), array([-6.49362993], dtype=float32))
# LineR: (array([-0.70028394], dtype=float32), array([ 640.33666992], dtype=float32)) PLineR: (array([-0.70028394], dtype=float32), array([ 640.33666992], dtype=float32))
# LineL: (array([ 0.64919299], dtype=float32), array([-6.6606369], dtype=float32)) PLineL: (array([ 0.64919299], dtype=float32), array([-6.6606369], dtype=float32))
# LineR: (array([-0.7000137], dtype=float32), array([ 640.20623779], dtype=float32)) PLineR: (array([-0.7000137], dtype=float32), array([ 640.20623779], dtype=float32))
# LineL: (array([ 0.64943838], dtype=float32), array([-6.75658464], dtype=float32)) PLineL: (array([ 0.64943838], dtype=float32), array([-6.75658464], dtype=float32))
# LineR: (array([-0.69955486], dtype=float32), array([ 640.0111084], dtype=float32)) PLineR: (array([-0.69955486], dtype=float32), array([ 640.0111084], dtype=float32))
# LineL: (array([ 0.64958662], dtype=float32), array([-6.85341835], dtype=float32)) PLineL: (array([ 0.64958662], dtype=float32), array([-6.85341835], dtype=float32))
#  44%|████▎     | 97/222 [00:03<00:04, 27.75it/s]
# LineR: (array([-0.69922191], dtype=float32), array([ 639.86474609], dtype=float32)) PLineR: (array([-0.69922191], dtype=float32), array([ 639.86474609], dtype=float32))
# LineL: (array([ 0.64980245], dtype=float32), array([-6.95673609], dtype=float32)) PLineL: (array([ 0.64980245], dtype=float32), array([-6.95673609], dtype=float32))
#  45%|████▌     | 100/222 [00:03<00:04, 27.59it/s]
# LineR: (array([-0.69889474], dtype=float32), array([ 639.69342041], dtype=float32)) PLineR: (array([-0.69889474], dtype=float32), array([ 639.69342041], dtype=float32))
# LineL: (array([ 0.64991426], dtype=float32), array([-7.03345823], dtype=float32)) PLineL: (array([ 0.64991426], dtype=float32), array([-7.03345823], dtype=float32))
# LineR: (array([-0.69858837], dtype=float32), array([ 639.53076172], dtype=float32)) PLineR: (array([-0.69858837], dtype=float32), array([ 639.53076172], dtype=float32))
# LineL: (array([ 0.64999056], dtype=float32), array([-7.10155821], dtype=float32)) PLineL: (array([ 0.64999056], dtype=float32), array([-7.10155821], dtype=float32))
# LineR: (array([-0.69827026], dtype=float32), array([ 639.36419678], dtype=float32)) PLineR: (array([-0.69827026], dtype=float32), array([ 639.36419678], dtype=float32))
# LineL: (array([ 0.65036738], dtype=float32), array([-7.32081747], dtype=float32)) PLineL: (array([ 0.65036738], dtype=float32), array([-7.32081747], dtype=float32))
# LineR: (array([-0.69781768], dtype=float32), array([ 639.18292236], dtype=float32)) PLineR: (array([-0.69781768], dtype=float32), array([ 639.18292236], dtype=float32))
# LineL: (array([ 0.6505636], dtype=float32), array([-7.46185398], dtype=float32)) PLineL: (array([ 0.6505636], dtype=float32), array([-7.46185398], dtype=float32))
# LineR: (array([-0.69754785], dtype=float32), array([ 639.07263184], dtype=float32)) PLineR: (array([-0.69754785], dtype=float32), array([ 639.07263184], dtype=float32))
# LineL: (array([ 0.65073878], dtype=float32), array([-7.5457325], dtype=float32)) PLineL: (array([ 0.65073878], dtype=float32), array([-7.5457325], dtype=float32))
#  46%|████▋     | 103/222 [00:03<00:04, 27.31it/s]
# LineR: (array([-0.69746876], dtype=float32), array([ 639.0425415], dtype=float32)) PLineR: (array([-0.69746876], dtype=float32), array([ 639.0425415], dtype=float32))
# LineL: (array([ 0.65101755], dtype=float32), array([-7.70402479], dtype=float32)) PLineL: (array([ 0.65101755], dtype=float32), array([-7.70402479], dtype=float32))
#  48%|████▊     | 106/222 [00:03<00:04, 27.71it/s]
# LineR: (array([-0.69757283], dtype=float32), array([ 639.09436035], dtype=float32)) PLineR: (array([-0.69757283], dtype=float32), array([ 639.09436035], dtype=float32))
# LineL: (array([ 0.65131897], dtype=float32), array([-7.87593269], dtype=float32)) PLineL: (array([ 0.65131897], dtype=float32), array([-7.87593269], dtype=float32))
# LineR: (array([-0.69733673], dtype=float32), array([ 639.02008057], dtype=float32)) PLineR: (array([-0.69733673], dtype=float32), array([ 639.02008057], dtype=float32))
# LineL: (array([ 0.65165573], dtype=float32), array([-8.0963583], dtype=float32)) PLineL: (array([ 0.65165573], dtype=float32), array([-8.0963583], dtype=float32))
# LineR: (array([-0.69735551], dtype=float32), array([ 639.0333252], dtype=float32)) PLineR: (array([-0.69735551], dtype=float32), array([ 639.0333252], dtype=float32))
# LineL: (array([ 0.65184557], dtype=float32), array([-8.24438953], dtype=float32)) PLineL: (array([ 0.65184557], dtype=float32), array([-8.24438953], dtype=float32))
# LineR: (array([-0.69731426], dtype=float32), array([ 639.01824951], dtype=float32)) PLineR: (array([-0.69731426], dtype=float32), array([ 639.01824951], dtype=float32))
# LineL: (array([ 0.65205735], dtype=float32), array([-8.34485817], dtype=float32)) PLineL: (array([ 0.65205735], dtype=float32), array([-8.34485817], dtype=float32))
# LineR: (array([-0.69718581], dtype=float32), array([ 638.96685791], dtype=float32)) PLineR: (array([-0.69718581], dtype=float32), array([ 638.96685791], dtype=float32))
# LineL: (array([ 0.65227818], dtype=float32), array([-8.47309494], dtype=float32)) PLineL: (array([ 0.65227818], dtype=float32), array([-8.47309494], dtype=float32))
#  49%|████▉     | 109/222 [00:03<00:04, 27.15it/s]
# LineR: (array([-0.69688761], dtype=float32), array([ 638.87237549], dtype=float32)) PLineR: (array([-0.69688761], dtype=float32), array([ 638.87237549], dtype=float32))
# LineL: (array([ 0.65259045], dtype=float32), array([-8.68189335], dtype=float32)) PLineL: (array([ 0.65259045], dtype=float32), array([-8.68189335], dtype=float32))
#  50%|█████     | 112/222 [00:04<00:04, 26.98it/s]
# LineR: (array([-0.6966995], dtype=float32), array([ 638.82263184], dtype=float32)) PLineR: (array([-0.6966995], dtype=float32), array([ 638.82263184], dtype=float32))
# LineL: (array([ 0.65275943], dtype=float32), array([-8.78589249], dtype=float32)) PLineL: (array([ 0.65275943], dtype=float32), array([-8.78589249], dtype=float32))
# LineR: (array([-0.696814], dtype=float32), array([ 638.85668945], dtype=float32)) PLineR: (array([-0.696814], dtype=float32), array([ 638.85668945], dtype=float32))
# LineL: (array([ 0.65277892], dtype=float32), array([-8.80312824], dtype=float32)) PLineL: (array([ 0.65277892], dtype=float32), array([-8.80312824], dtype=float32))
# LineR: (array([-0.69698232], dtype=float32), array([ 638.92584229], dtype=float32)) PLineR: (array([-0.69698232], dtype=float32), array([ 638.92584229], dtype=float32))
# LineL: (array([ 0.65281981], dtype=float32), array([-8.83492661], dtype=float32)) PLineL: (array([ 0.65281981], dtype=float32), array([-8.83492661], dtype=float32))
# LineR: (array([-0.69673222], dtype=float32), array([ 638.83551025], dtype=float32)) PLineR: (array([-0.69673222], dtype=float32), array([ 638.83551025], dtype=float32))
# LineL: (array([ 0.65309358], dtype=float32), array([-9.02458096], dtype=float32)) PLineL: (array([ 0.65309358], dtype=float32), array([-9.02458096], dtype=float32))
# LineR: (array([-0.69671839], dtype=float32), array([ 638.82171631], dtype=float32)) PLineR: (array([-0.69671839], dtype=float32), array([ 638.82171631], dtype=float32))
# LineL: (array([ 0.65334767], dtype=float32), array([-9.19153976], dtype=float32)) PLineL: (array([ 0.65334767], dtype=float32), array([-9.19153976], dtype=float32))
#  52%|█████▏    | 115/222 [00:04<00:03, 26.82it/s]
# LineR: (array([-0.69641733], dtype=float32), array([ 638.70440674], dtype=float32)) PLineR: (array([-0.69641733], dtype=float32), array([ 638.70440674], dtype=float32))
# LineL: (array([ 0.65336448], dtype=float32), array([-9.20157909], dtype=float32)) PLineL: (array([ 0.65336448], dtype=float32), array([-9.20157909], dtype=float32))
#  53%|█████▎    | 118/222 [00:04<00:03, 27.36it/s]
# LineR: (array([-0.69635385], dtype=float32), array([ 638.68383789], dtype=float32)) PLineR: (array([-0.69635385], dtype=float32), array([ 638.68383789], dtype=float32))
# LineL: (array([ 0.653543], dtype=float32), array([-9.36316013], dtype=float32)) PLineL: (array([ 0.653543], dtype=float32), array([-9.36316013], dtype=float32))
# LineR: (array([-0.696455], dtype=float32), array([ 638.71588135], dtype=float32)) PLineR: (array([-0.696455], dtype=float32), array([ 638.71588135], dtype=float32))
# LineL: (array([ 0.65360188], dtype=float32), array([-9.41592503], dtype=float32)) PLineL: (array([ 0.65360188], dtype=float32), array([-9.41592503], dtype=float32))
# LineR: (array([-0.69618338], dtype=float32), array([ 638.61218262], dtype=float32)) PLineR: (array([-0.69618338], dtype=float32), array([ 638.61218262], dtype=float32))
# LineL: (array([ 0.65362954], dtype=float32), array([-9.42919636], dtype=float32)) PLineL: (array([ 0.65362954], dtype=float32), array([-9.42919636], dtype=float32))
# LineR: (array([-0.69595027], dtype=float32), array([ 638.51586914], dtype=float32)) PLineR: (array([-0.69595027], dtype=float32), array([ 638.51586914], dtype=float32))
# LineL: (array([ 0.6537028], dtype=float32), array([-9.49858189], dtype=float32)) PLineL: (array([ 0.6537028], dtype=float32), array([-9.49858189], dtype=float32))
# LineR: (array([-0.69580799], dtype=float32), array([ 638.45825195], dtype=float32)) PLineR: (array([-0.69580799], dtype=float32), array([ 638.45825195], dtype=float32))
# LineL: (array([ 0.6537652], dtype=float32), array([-9.57136726], dtype=float32)) PLineL: (array([ 0.6537652], dtype=float32), array([-9.57136726], dtype=float32))
#  55%|█████▍    | 121/222 [00:04<00:03, 27.60it/s]
# LineR: (array([-0.69596273], dtype=float32), array([ 638.50427246], dtype=float32)) PLineR: (array([-0.69596273], dtype=float32), array([ 638.50427246], dtype=float32))
# LineL: (array([ 0.65374434], dtype=float32), array([-9.57027721], dtype=float32)) PLineL: (array([ 0.65374434], dtype=float32), array([-9.57027721], dtype=float32))
#  56%|█████▌    | 124/222 [00:04<00:03, 27.41it/s]
# LineR: (array([-0.69588983], dtype=float32), array([ 638.48400879], dtype=float32)) PLineR: (array([-0.69588983], dtype=float32), array([ 638.48400879], dtype=float32))
# LineL: (array([ 0.65377188], dtype=float32), array([-9.6048975], dtype=float32)) PLineL: (array([ 0.65377188], dtype=float32), array([-9.6048975], dtype=float32))
# LineR: (array([-0.69603258], dtype=float32), array([ 638.51531982], dtype=float32)) PLineR: (array([-0.69603258], dtype=float32), array([ 638.51531982], dtype=float32))
# LineL: (array([ 0.65387928], dtype=float32), array([-9.68183708], dtype=float32)) PLineL: (array([ 0.65387928], dtype=float32), array([-9.68183708], dtype=float32))
# LineR: (array([-0.69589072], dtype=float32), array([ 638.46563721], dtype=float32)) PLineR: (array([-0.69589072], dtype=float32), array([ 638.46563721], dtype=float32))
# LineL: (array([ 0.6539467], dtype=float32), array([-9.73512936], dtype=float32)) PLineL: (array([ 0.6539467], dtype=float32), array([-9.73512936], dtype=float32))
# LineR: (array([-0.69572902], dtype=float32), array([ 638.40759277], dtype=float32)) PLineR: (array([-0.69572902], dtype=float32), array([ 638.40759277], dtype=float32))
# LineL: (array([ 0.65401804], dtype=float32), array([-9.81568623], dtype=float32)) PLineL: (array([ 0.65401804], dtype=float32), array([-9.81568623], dtype=float32))
# LineR: (array([-0.69522542], dtype=float32), array([ 638.24334717], dtype=float32)) PLineR: (array([-0.69522542], dtype=float32), array([ 638.24334717], dtype=float32))
# LineL: (array([ 0.65391397], dtype=float32), array([-9.75215244], dtype=float32)) PLineL: (array([ 0.65391397], dtype=float32), array([-9.75215244], dtype=float32))
#  57%|█████▋    | 127/222 [00:04<00:03, 27.47it/s]
# LineR: (array([-0.69521934], dtype=float32), array([ 638.26171875], dtype=float32)) PLineR: (array([-0.69521934], dtype=float32), array([ 638.26171875], dtype=float32))
# LineL: (array([ 0.65372974], dtype=float32), array([-9.63962173], dtype=float32)) PLineL: (array([ 0.65372974], dtype=float32), array([-9.63962173], dtype=float32))
#  59%|█████▊    | 130/222 [00:04<00:03, 27.60it/s]
# LineR: (array([-0.69530421], dtype=float32), array([ 638.32452393], dtype=float32)) PLineR: (array([-0.69530421], dtype=float32), array([ 638.32452393], dtype=float32))
# LineL: (array([ 0.65369886], dtype=float32), array([-9.63000679], dtype=float32)) PLineL: (array([ 0.65369886], dtype=float32), array([-9.63000679], dtype=float32))
# LineR: (array([-0.69557464], dtype=float32), array([ 638.45336914], dtype=float32)) PLineR: (array([-0.69557464], dtype=float32), array([ 638.45336914], dtype=float32))
# LineL: (array([ 0.65357214], dtype=float32), array([-9.55921078], dtype=float32)) PLineL: (array([ 0.65357214], dtype=float32), array([-9.55921078], dtype=float32))
# LineR: (array([-0.69548458], dtype=float32), array([ 638.46295166], dtype=float32)) PLineR: (array([-0.69548458], dtype=float32), array([ 638.46295166], dtype=float32))
# LineL: (array([ 0.65357661], dtype=float32), array([-9.56560421], dtype=float32)) PLineL: (array([ 0.65357661], dtype=float32), array([-9.56560421], dtype=float32))
# LineR: (array([-0.69557184], dtype=float32), array([ 638.53826904], dtype=float32)) PLineR: (array([-0.69557184], dtype=float32), array([ 638.53826904], dtype=float32))
# LineL: (array([ 0.65350246], dtype=float32), array([-9.55762577], dtype=float32)) PLineL: (array([ 0.65350246], dtype=float32), array([-9.55762577], dtype=float32))
# LineR:
#  (array([-0.69557691], dtype=float32), array([ 638.59338379], dtype=float32)) PLineR: (array([-0.69557691], dtype=float32), array([ 638.59338379], dtype=float32))
# LineL: (array([ 0.65339214], dtype=float32), array([-9.51207924], dtype=float32)) PLineL: (array([ 0.65339214], dtype=float32), array([-9.51207924], dtype=float32))
#  60%|█████▉    | 133/222 [00:04<00:03, 25.13it/s]
# LineR: (array([-0.69585484], dtype=float32), array([ 638.72601318], dtype=float32)) PLineR: (array([-0.69585484], dtype=float32), array([ 638.72601318], dtype=float32))
# LineL: (array([ 0.65323675], dtype=float32), array([-9.43480587], dtype=float32)) PLineL: (array([ 0.65323675], dtype=float32), array([-9.43480587], dtype=float32))
# LineR: (array([-0.6960451], dtype=float32), array([ 638.8102417], dtype=float32)) PLineR: (array([-0.6960451], dtype=float32), array([ 638.8102417], dtype=float32))
# LineL: (array([ 0.65310282], dtype=float32), array([-9.37382603], dtype=float32)) PLineL: (array([ 0.65310282], dtype=float32), array([-9.37382603], dtype=float32))
# LineR: (array([-0.69622713], dtype=float32), array([ 638.8649292], dtype=float32)) PLineR: (array([-0.69622713], dtype=float32), array([ 638.8649292], dtype=float32))
# LineL: (array([ 0.65300971], dtype=float32), array([-9.33417416], dtype=float32)) PLineL: (array([ 0.65300971], dtype=float32), array([-9.33417416], dtype=float32))
# LineR:
#  61%|██████▏   | 136/222 [00:05<00:06, 13.78it/s]
#
#
#
#
#
#  63%|██████▎   | 139/222 [00:05<00:05, 16.18it/s]
# (array([-0.69629705], dtype=float32), array([ 638.89093018], dtype=float32)) PLineR: (array([-0.69629705], dtype=float32), array([ 638.89093018], dtype=float32))
# ...
# LineR: (array([-0.70591569], dtype=float32), array([ 644.30236816], dtype=float32)) PLineR: (array([-0.70591569], dtype=float32), array([ 644.30236816], dtype=float32))
# LineL: (array([ 0.6475569], dtype=float32), array([-7.44221687], dtype=float32)) PLineL: (array([ 0.6475569], dtype=float32), array([-7.44221687], dtype=float32))
#  80%|████████  | 178/222 [00:06<00:01, 26.62it/s]
#
#
#
#
#  82%|████████▏ | 181/222 [00:06<00:01, 27.26it/s]
# LineR: (array([-0.70629787], dtype=float32), array([ 644.52246094], dtype=float32)) PLineR: (array([-0.70629787], dtype=float32), array([ 644.52246094], dtype=float32))
# LineL: (array([ 0.64732087], dtype=float32), array([-7.31611824], dtype=float32)) PLineL: (array([ 0.64732087], dtype=float32), array([-7.31611824], dtype=float32))
# LineR: (array([-0.70663142], dtype=float32), array([ 644.7097168], dtype=float32)) PLineR: (array([-0.70663142], dtype=float32), array([ 644.7097168], dtype=float32))
# LineL: (array([ 0.64717329], dtype=float32), array([-7.27560902], dtype=float32)) PLineL: (array([ 0.64717329], dtype=float32), array([-7.27560902], dtype=float32))
# LineR: (array([-0.70683515], dtype=float32), array([ 644.83996582], dtype=float32)) PLineR: (array([-0.70683515], dtype=float32), array([ 644.83996582], dtype=float32))
# LineL: (array([ 0.64708674], dtype=float32), array([-7.24795628], dtype=float32)) PLineL: (array([ 0.64708674], dtype=float32), array([-7.24795628], dtype=float32))
# LineR: (array([-0.70716631], dtype=float32), array([ 645.01165771], dtype=float32)) PLineR: (array([-0.70716631], dtype=float32), array([ 645.01165771], dtype=float32))
# LineL: (array([ 0.64685917], dtype=float32), array([-7.13800478], dtype=float32)) PLineL: (array([ 0.64685917], dtype=float32), array([-7.13800478], dtype=float32))
# LineR: (array([-0.70743495], dtype=float32), array([ 645.16943359], dtype=float32)) PLineR: (array([-0.70743495], dtype=float32), array([ 645.16943359], dtype=float32))
# LineL: (array([ 0.64671624], dtype=float32), array([-7.08788013], dtype=float32)) PLineL: (array([ 0.64671624], dtype=float32), array([-7.08788013], dtype=float32))
# LineR: (array([-0.7078346], dtype=float32), array([ 645.35601807], dtype=float32)) PLineR: (array([-0.7078346], dtype=float32), array([ 645.35601807], dtype=float32))
# LineL: (array([ 0.64656633], dtype=float32), array([-7.03825808], dtype=float32)) PLineL: (array([ 0.64656633], dtype=float32), array([-7.03825808], dtype=float32))
#  83%|████████▎ | 184/222 [00:07<00:01, 26.50it/s]
#
#
#
#
#  84%|████████▍ | 187/222 [00:07<00:01, 27.11it/s]
# LineR: (array([-0.70803964], dtype=float32), array([ 645.49621582], dtype=float32)) PLineR: (array([-0.70803964], dtype=float32), array([ 645.49621582], dtype=float32))
# LineL: (array([ 0.64646405], dtype=float32), array([-7.02891159], dtype=float32)) PLineL: (array([ 0.64646405], dtype=float32), array([-7.02891159], dtype=float32))
# LineR: (array([-0.70838064], dtype=float32), array([ 645.68896484], dtype=float32)) PLineR: (array([-0.70838064], dtype=float32), array([ 645.68896484], dtype=float32))
# LineL: (array([ 0.64632499], dtype=float32), array([-6.97468424], dtype=float32)) PLineL: (array([ 0.64632499], dtype=float32), array([-6.97468424], dtype=float32))
# LineR: (array([-0.70860475], dtype=float32), array([ 645.80395508], dtype=float32)) PLineR: (array([-0.70860475], dtype=float32), array([ 645.80395508], dtype=float32))
# LineL: (array([ 0.6461578], dtype=float32), array([-6.91130304], dtype=float32)) PLineL: (array([ 0.6461578], dtype=float32), array([-6.91130304], dtype=float32))
# LineR: (array([-0.70890117], dtype=float32), array([ 645.94689941], dtype=float32)) PLineR: (array([-0.70890117], dtype=float32), array([ 645.94689941], dtype=float32))
# LineL: (array([ 0.64592969], dtype=float32), array([-6.79997396], dtype=float32)) PLineL: (array([ 0.64592969], dtype=float32), array([-6.79997396], dtype=float32))
# LineR: (array([-0.70918405], dtype=float32), array([ 646.07727051], dtype=float32)) PLineR: (array([-0.70918405], dtype=float32), array([ 646.07727051], dtype=float32))
# LineL: (array([ 0.64583588], dtype=float32), array([-6.76844215], dtype=float32)) PLineL: (array([ 0.64583588], dtype=float32), array([-6.76844215], dtype=float32))
# LineR: (array([-0.70951891], dtype=float32), array([ 646.23382568], dtype=float32)) PLineR: (array([-0.70951891], dtype=float32), array([ 646.23382568], dtype=float32))
# LineL: (array([ 0.64583588], dtype=float32), array([-6.76844215], dtype=float32)) PLineL: (array([ 0.64583588], dtype=float32), array([-6.76844215], dtype=float32))
#  86%|████████▌ | 190/222 [00:07<00:01, 27.47it/s]
#
#
#
#
#  87%|████████▋ | 193/222 [00:07<00:01, 27.51it/s]
# LineR: (array([-0.70987278], dtype=float32), array([ 646.371521], dtype=float32)) PLineR: (array([-0.70987278], dtype=float32), array([ 646.371521], dtype=float32))
# LineL: (array([ 0.64577663], dtype=float32), array([-6.8047142], dtype=float32)) PLineL: (array([ 0.64577663], dtype=float32), array([-6.8047142], dtype=float32))
# LineR: (array([-0.71005255], dtype=float32), array([ 646.4586792], dtype=float32)) PLineR: (array([-0.71005255], dtype=float32), array([ 646.4586792], dtype=float32))
# LineL: (array([ 0.64577258], dtype=float32), array([-6.83354425], dtype=float32)) PLineL: (array([ 0.64577258], dtype=float32), array([-6.83354425], dtype=float32))
# LineR: (array([-0.7102831], dtype=float32), array([ 646.57250977], dtype=float32)) PLineR: (array([-0.7102831], dtype=float32), array([ 646.57250977], dtype=float32))
# LineL: (array([ 0.64565998], dtype=float32), array([-6.81060648], dtype=float32)) PLineL: (array([ 0.64565998], dtype=float32), array([-6.81060648], dtype=float32))
# LineR: (array([-0.71060729], dtype=float32), array([ 646.72790527], dtype=float32)) PLineR: (array([-0.71060729], dtype=float32), array([ 646.72790527], dtype=float32))
# LineL: (array([ 0.64565998], dtype=float32), array([-6.81060648], dtype=float32)) PLineL: (array([ 0.64565998], dtype=float32), array([-6.81060648], dtype=float32))
# LineR: (array([-0.71092588], dtype=float32), array([ 646.88354492], dtype=float32)) PLineR: (array([-0.71092588], dtype=float32), array([ 646.88354492], dtype=float32))
# LineL: (array([ 0.64546949], dtype=float32), array([-6.78334427], dtype=float32)) PLineL: (array([ 0.64546949], dtype=float32), array([-6.78334427], dtype=float32))
# LineR: (array([-0.71112734], dtype=float32), array([ 647.00640869], dtype=float32)) PLineR: (array([-0.71112734], dtype=float32), array([ 647.00640869], dtype=float32))
# LineL: (array([ 0.64530611], dtype=float32), array([-6.70744181], dtype=float32)) PLineL: (array([ 0.64530611], dtype=float32), array([-6.70744181], dtype=float32))
#  88%|████████▊ | 196/222 [00:07<00:00, 27.23it/s]
#
#
#
#
#  90%|████████▉ | 199/222 [00:07<00:00, 27.82it/s]
# LineR: (array([-0.71140885], dtype=float32), array([ 647.16125488], dtype=float32)) PLineR: (array([-0.71140885], dtype=float32), array([ 647.16125488], dtype=float32))
# LineL: (array([ 0.64530611], dtype=float32), array([-6.70744181], dtype=float32)) PLineL: (array([ 0.64530611], dtype=float32), array([-6.70744181], dtype=float32))
# LineR: (array([-0.71169347], dtype=float32), array([ 647.30218506], dtype=float32)) PLineR: (array([-0.71169347], dtype=float32), array([ 647.30218506], dtype=float32))
# LineL: (array([ 0.64518213], dtype=float32), array([-6.6829567], dtype=float32)) PLineL: (array([ 0.64518213], dtype=float32), array([-6.6829567], dtype=float32))
# LineR: (array([-0.71185786], dtype=float32), array([ 647.39306641], dtype=float32)) PLineR: (array([-0.71185786], dtype=float32), array([ 647.39306641], dtype=float32))
# LineL: (array([ 0.64507794], dtype=float32), array([-6.64303732], dtype=float32)) PLineL: (array([ 0.64507794], dtype=float32), array([-6.64303732], dtype=float32))
# LineR: (array([-0.71212029], dtype=float32), array([ 647.52075195], dtype=float32)) PLineR: (array([-0.71212029], dtype=float32), array([ 647.52075195], dtype=float32))
# LineL: (array([ 0.64499778], dtype=float32), array([-6.6343956], dtype=float32)) PLineL: (array([ 0.64499778], dtype=float32), array([-6.6343956], dtype=float32))
# LineR: (array([-0.71235055], dtype=float32), array([ 647.63970947], dtype=float32)) PLineR: (array([-0.71235055], dtype=float32), array([ 647.63970947], dtype=float32))
# LineL: (array([ 0.64489776], dtype=float32), array([-6.59039688], dtype=float32)) PLineL: (array([ 0.64489776], dtype=float32), array([-6.59039688], dtype=float32))
# LineR: (array([-0.71257347], dtype=float32), array([ 647.7635498], dtype=float32)) PLineR: (array([-0.71257347], dtype=float32), array([ 647.7635498], dtype=float32))
# LineL: (array([ 0.64469415], dtype=float32), array([-6.50161171], dtype=float32)) PLineL: (array([ 0.64469415], dtype=float32), array([-6.50161171], dtype=float32))
#  91%|█████████ | 202/222 [00:07<00:00, 28.17it/s]
#
#
#
#
#  92%|█████████▏| 205/222 [00:07<00:00, 27.74it/s]
# LineR: (array([-0.71293205], dtype=float32), array([ 647.91845703], dtype=float32)) PLineR: (array([-0.71293205], dtype=float32), array([ 647.91845703], dtype=float32))
# LineL: (array([ 0.64469415], dtype=float32), array([-6.50161171], dtype=float32)) PLineL: (array([ 0.64469415], dtype=float32), array([-6.50161171], dtype=float32))
# LineR: (array([-0.71313542], dtype=float32), array([ 648.02819824], dtype=float32)) PLineR: (array([-0.71313542], dtype=float32), array([ 648.02819824], dtype=float32))
# LineL: (array([ 0.64469415], dtype=float32), array([-6.50161171], dtype=float32)) PLineL: (array([ 0.64469415], dtype=float32), array([-6.50161171], dtype=float32))
# LineR: (array([-0.71350873], dtype=float32), array([ 648.19067383], dtype=float32)) PLineR: (array([-0.71350873], dtype=float32), array([ 648.19067383], dtype=float32))
# LineL: (array([ 0.64457446], dtype=float32), array([-6.4427948], dtype=float32)) PLineL: (array([ 0.64457446], dtype=float32), array([-6.4427948], dtype=float32))
# LineR: (array([-0.71382743], dtype=float32), array([ 648.34381104], dtype=float32)) PLineR: (array([-0.71382743], dtype=float32), array([ 648.34381104], dtype=float32))
# LineL: (array([ 0.64457446], dtype=float32), array([-6.4427948], dtype=float32)) PLineL: (array([ 0.64457446], dtype=float32), array([-6.4427948], dtype=float32))
# LineR: (array([-0.71402651], dtype=float32), array([ 648.45050049], dtype=float32)) PLineR: (array([-0.71402651], dtype=float32), array([ 648.45050049], dtype=float32))
# LineL: (array([ 0.64457446], dtype=float32), array([-6.4427948], dtype=float32)) PLineL: (array([ 0.64457446], dtype=float32), array([-6.4427948], dtype=float32))
# LineR: (array([-0.71422559], dtype=float32), array([ 648.55718994], dtype=float32)) PLineR: (array([-0.71422559], dtype=float32), array([ 648.55718994], dtype=float32))
# LineL: (array([ 0.64439678], dtype=float32), array([-6.38571692], dtype=float32)) PLineL: (array([ 0.64439678], dtype=float32), array([-6.38571692], dtype=float32))
#  94%|█████████▎| 208/222 [00:07<00:00, 27.80it/s]
#
#
#
#
#  95%|█████████▌| 211/222 [00:08<00:00, 28.07it/s]
# LineR: (array([-0.71443266], dtype=float32), array([ 648.66485596], dtype=float32)) PLineR: (array([-0.71443266], dtype=float32), array([ 648.66485596], dtype=float32))
# LineL: (array([ 0.64439678], dtype=float32), array([-6.38571692], dtype=float32)) PLineL: (array([ 0.64439678], dtype=float32), array([-6.38571692], dtype=float32))
# LineR: (array([-0.71476382], dtype=float32), array([ 648.80682373], dtype=float32)) PLineR: (array([-0.71476382], dtype=float32), array([ 648.80682373], dtype=float32))
# LineL: (array([ 0.64439678], dtype=float32), array([-6.38571692], dtype=float32)) PLineL: (array([ 0.64439678], dtype=float32), array([-6.38571692], dtype=float32))
# LineR: (array([-0.7146737], dtype=float32), array([ 648.78643799], dtype=float32)) PLineR: (array([-0.7146737], dtype=float32), array([ 648.78643799], dtype=float32))
# LineL: (array([ 0.64439678], dtype=float32), array([-6.38571692], dtype=float32)) PLineL: (array([ 0.64439678], dtype=float32), array([-6.38571692], dtype=float32))
# LineR: (array([-0.7146737], dtype=float32), array([ 648.78643799], dtype=float32)) PLineR: (array([-0.7146737], dtype=float32), array([ 648.78643799], dtype=float32))
# LineL: (array([ 0.64439678], dtype=float32), array([-6.38571692], dtype=float32)) PLineL: (array([ 0.64439678], dtype=float32), array([-6.38571692], dtype=float32))
# LineR: (array([-0.71496248], dtype=float32), array([ 648.91595459], dtype=float32)) PLineR: (array([-0.71496248], dtype=float32), array([ 648.91595459], dtype=float32))
# LineL: (array([ 0.64439678], dtype=float32), array([-6.38571692], dtype=float32)) PLineL: (array([ 0.64439678], dtype=float32), array([-6.38571692], dtype=float32))
# LineR: (array([-0.71514815], dtype=float32), array([ 649.02032471], dtype=float32)) PLineR: (array([-0.71514815], dtype=float32), array([ 649.02032471], dtype=float32))
# LineL: (array([ 0.64439678], dtype=float32), array([-6.38571692], dtype=float32)) PLineL: (array([ 0.64439678], dtype=float32), array([-6.38571692], dtype=float32))
#  96%|█████████▋| 214/222 [00:08<00:00, 27.90it/s]
#
#
#
#
#  98%|█████████▊| 217/222 [00:08<00:00, 27.70it/s]
# LineR: (array([-0.71527702], dtype=float32), array([ 649.09637451], dtype=float32)) PLineR: (array([-0.71527702], dtype=float32), array([ 649.09637451], dtype=float32))
# LineL: (array([ 0.64439678], dtype=float32), array([-6.38571692], dtype=float32)) PLineL: (array([ 0.64439678], dtype=float32), array([-6.38571692], dtype=float32))
# LineR: (array([-0.71547729], dtype=float32), array([ 649.19970703], dtype=float32)) PLineR: (array([-0.71547729], dtype=float32), array([ 649.19970703], dtype=float32))
# LineL: (array([ 0.64439678], dtype=float32), array([-6.38571692], dtype=float32)) PLineL: (array([ 0.64439678], dtype=float32), array([-6.38571692], dtype=float32))
# LineR: (array([-0.71564299], dtype=float32), array([ 649.29638672], dtype=float32)) PLineR: (array([-0.71564299], dtype=float32), array([ 649.29638672], dtype=float32))
# LineL: (array([ 0.64439678], dtype=float32), array([-6.38571692], dtype=float32)) PLineL: (array([ 0.64439678], dtype=float32), array([-6.38571692], dtype=float32))
# LineR: (array([-0.71591908], dtype=float32), array([ 649.44958496], dtype=float32)) PLineR: (array([-0.71591908], dtype=float32), array([ 649.44958496], dtype=float32))
# LineL: (array([ 0.64439678], dtype=float32), array([-6.38571692], dtype=float32)) PLineL: (array([ 0.64439678], dtype=float32), array([-6.38571692], dtype=float32))
# LineR: (array([-0.71618724], dtype=float32), array([ 649.57501221], dtype=float32)) PLineR: (array([-0.71618724], dtype=float32), array([ 649.57501221], dtype=float32))
# LineL: (array([ 0.64450037], dtype=float32), array([-6.43762493], dtype=float32)) PLineL: (array([ 0.64450037], dtype=float32), array([-6.43762493], dtype=float32))
# LineR: (array([-0.71642983], dtype=float32), array([ 649.68890381], dtype=float32)) PLineR: (array([-0.71642983], dtype=float32), array([ 649.68890381], dtype=float32))
# LineL: (array([ 0.64437562], dtype=float32), array([-6.3605504], dtype=float32)) PLineL: (array([ 0.64437562], dtype=float32), array([-6.3605504], dtype=float32))
#  99%|█████████▉| 220/222 [00:08<00:00, 27.53it/s]
#
#
#
#
# 100%|█████████▉| 221/222 [00:08<00:00, 26.30it/s]
# LineR: (array([-0.71662396], dtype=float32), array([ 649.7902832], dtype=float32)) PLineR: (array([-0.71662396], dtype=float32), array([ 649.7902832], dtype=float32))
# LineL: (array([ 0.64440119], dtype=float32), array([-6.38136435], dtype=float32)) PLineL: (array([ 0.64440119], dtype=float32), array([-6.38136435], dtype=float32))
# LineR: (array([-0.71693569], dtype=float32), array([ 649.93701172], dtype=float32)) PLineR: (array([-0.71693569], dtype=float32), array([ 649.93701172], dtype=float32))
# LineL: (array([ 0.64440119], dtype=float32), array([-6.38136435], dtype=float32)) PLineL: (array([ 0.64440119], dtype=float32), array([-6.38136435], dtype=float32))
# [MoviePy] Done.
# [MoviePy] >>>> Video ready: test_videos_output/solidWhiteRight.mp4
#
# CPU times: user 7.3 s, sys: 3.31 s, total: 10.6 s
# Wall time: 9 s

# %% [markdown]
# Play the video inline, or if you prefer find the video in your filesystem (should be in the same directory) and play it in your video player of choice.

# %%
HTML("""
<video width="960" height="540" controls>
  <source src="{0}">
</video>
""".format(white_output))
# Out:
# <video width="960" height="540" controls>
#   <source src="test_videos_output/solidWhiteRight.mp4">
# </video>

# %% [markdown]
# ## Improve the draw_lines() function
#
# **At this point, if you were successful with making the pipeline and tuning parameters, you probably have the Hough line segments drawn onto the road, but what about identifying the full extent of the lane and marking it clearly as in the example video (P1_example.mp4)?  Think about defining a line to run the full length of the visible lane based on the line segments you identified with the Hough Transform. As mentioned previously, try to average and/or extrapolate the line segments you've detected to map out the full extent of the lane lines. You can see an example of the result you're going for in the video "P1_example.mp4".**
#
# **Go back and modify your draw_lines function accordingly and try re-running your pipeline. The new output should draw a single, solid line over the left lane line and a single, solid line over the right lane line. The lines should start from the bottom of the image and extend out to the top of the region of interest.**

# %% [markdown]
# Now for the one with the solid yellow lane on the left. This one's more tricky!

# %%
yellow_output = 'test_videos_output/solidYellowLeft.mp4'
clip2 = VideoFileClip('test_videos/solidYellowLeft.mp4')
yellow_clip = clip2.fl_image(process_image)
# %time yellow_clip.write_videofile(yellow_output, audio=False)
# Out:
# [MoviePy] >>>> Building video test_videos_output/solidYellowLeft.mp4
# [MoviePy] Writing video test_videos_output/solidYellowLeft.mp4
#   0%|          | 0/682 [00:00<?, ?it/s]
#   1%|          | 4/682 [00:00<00:20, 32.95it/s]
#   1%|          | 8/682 [00:00<00:20, 33.26it/s]
#   2%|▏         | 12/682 [00:00<00:20, 33.39it/s]
#   2%|▏         | 16/682 [00:00<00:20, 32.85it/s]
#   3%|▎         | 20/682 [00:00<00:19, 33.60it/s]
#   4%|▎         | 24/682 [00:00<00:19, 33.81it/s]
#   4%|▍         | 28/682 [00:00<00:19, 33.81it/s]
#   5%|▍         | 32/682 [00:00<00:19, 33.17it/s]
#   5%|▌         | 36/682 [00:01<00:19, 33.52it/s]
#   6%|▌         | 40/682 [00:01<00:19, 33.73it/s]
#   6%|▋         | 44/682 [00:01<00:19, 32.99it/s]
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-211-af3761e1318c> in <module>()
#       2 clip2 = VideoFileClip('test_videos/solidYellowLeft.mp4')
#       3 yellow_clip = clip2.fl_image(process_image)
# ----> 4 get_ipython().magic('time yellow_clip.write_videofile(yellow_output, audio=False)')
#
# /Users/Home/miniconda3/envs/carnd-term1/lib/python3.5/site-packages/IPython/core/interactiveshell.py in magic(self, arg_s)
#    2156         magic_name, _, magic_arg_s = arg_s.partition(' ')
#    2157         magic_name = magic_name.lstrip(prefilter.ESC_MAGIC)
# -> 2158         return self.run_line_magic(magic_name, magic_arg_s)
#    2159
#    2160     #-------------------------------------------------------------------------
#
# /Users/Home/miniconda3/envs/carnd-term1/lib/python3.5/site-packages/IPython/core/interactiveshell.py in run_line_magic(self, magic_name, line)
#    2077                 kwargs['local_ns'] = sys._getframe(stack_depth).f_locals
#    2078             with self.builtin_trap:
# -> 2079                 result = fn(*args,**kwargs)
#    2080             return result
#    2081
#
# <decorator-gen-59> in time(self, line, cell, local_ns)
#
# /Users/Home/miniconda3/envs/carnd-term1/lib/python3.5/site-packages/IPython/core/magic.py in <lambda>(f, *a, **k)
#     186     # but it's overkill for just that one bit of state.
#     187     def magic_deco(arg):
# --> 188         call = lambda f, *a, **k: f(*a, **k)
#     189
#     190         if callable(arg):
#
# /Users/Home/miniconda3/envs/carnd-term1/lib/python3.5/site-packages/IPython/core/magics/execution.py in time(self, line, cell, local_ns)
#    1179         if mode=='eval':
#    1180             st = clock2()
# -> 1181             out = eval(code, glob, local_ns)
#    1182             end = clock2()
#    1183         else:
#
# <timed eval> in <module>()
#
# <decorator-gen-172> in write_videofile(self, filename, fps, codec, bitrate, audio, audio_fps, preset, audio_nbytes, audio_codec, audio_bitrate, audio_bufsize, temp_audiofile, rewrite_audio, remove_temp, write_logfile, verbose, threads, ffmpeg_params)
#
# /Users/Home/miniconda3/envs/carnd-term1/lib/python3.5/site-packages/moviepy/decorators.py in requires_duration(f, clip, *a, **k)
#      52         raise ValueError("Attribute 'duration' not set")
#      53     else:
# ---> 54         return f(clip, *a, **k)
#      55
#      56
#
# <decorator-gen-171> in write_videofile(self, filename, fps, codec, bitrate, audio, audio_fps, preset, audio_nbytes, audio_codec, audio_bitrate, audio_bufsize, temp_audiofile, rewrite_audio, remove_temp, write_logfile, verbose, threads, ffmpeg_params)
#
# /Users/Home/miniconda3/envs/carnd-term1/lib/python3.5/site-packages/moviepy/decorators.py in use_clip_fps_by_default(f, clip, *a, **k)
#     135              for (k,v) in k.items()}
#     136
# --> 137     return f(clip, *new_a, **new_kw)
#
# <decorator-gen-170> in write_videofile(self, filename, fps, codec, bitrate, audio, audio_fps, preset, audio_nbytes, audio_codec, audio_bitrate, audio_bufsize, temp_audiofile, rewrite_audio, remove_temp, write_logfile, verbose, threads, ffmpeg_params)
#
# /Users/Home/miniconda3/envs/carnd-term1/lib/python3.5/site-packages/moviepy/decorators.py in convert_masks_to_RGB(f, clip, *a, **k)
#      20     if clip.ismask:
#      21         clip = clip.to_RGB()
# ---> 22     return f(clip, *a, **k)
#      23
#      24 @decorator.decorator
#
# /Users/Home/miniconda3/envs/carnd-term1/lib/python3.5/site-packages/moviepy/video/VideoClip.py in write_videofile(self, filename, fps, codec, bitrate, audio, audio_fps, preset, audio_nbytes, audio_codec, audio_bitrate, audio_bufsize, temp_audiofile, rewrite_audio, remove_temp, write_logfile, verbose, threads, ffmpeg_params)
#     336                            audiofile = audiofile,
#     337                            verbose=verbose, threads=threads,
# --> 338                            ffmpeg_params=ffmpeg_params)
#     339
#     340         if remove_temp and make_audio:
#
# /Users/Home/miniconda3/envs/carnd-term1/lib/python3.5/site-packages/moviepy/video/io/ffmpeg_writer.py in ffmpeg_write_video(clip, filename, fps, codec, bitrate, preset, withmask, write_logfile, audiofile, verbose, threads, ffmpeg_params)
#     214
#     215     for t,frame in clip.iter_frames(progress_bar=True, with_times=True,
# --> 216                                     fps=fps, dtype="uint8"):
#     217         if withmask:
#     218             mask = (255*clip.mask.get_frame(t))
#
# /Users/Home/miniconda3/envs/carnd-term1/lib/python3.5/site-packages/tqdm/_tqdm.py in __iter__(self)
#     831 """, fp_write=getattr(self.fp, 'write', sys.stderr.write))
#     832
# --> 833             for obj in iterable:
#     834                 yield obj
#     835                 # Update and print the progressbar.
#
# /Users/Home/miniconda3/envs/carnd-term1/lib/python3.5/site-packages/moviepy/Clip.py in generator()
#     471             for t in np.arange(0, self.duration, 1.0/fps):
#     472
# --> 473                 frame = self.get_frame(t)
#     474
#     475                 if (dtype is not None) and (frame.dtype != dtype):
#
# <decorator-gen-135> in get_frame(self, t)
#
# /Users/Home/miniconda3/envs/carnd-term1/lib/python3.5/site-packages/moviepy/decorators.py in wrapper(f, *a, **kw)
#      87         new_kw = {k: fun(v) if k in varnames else v
#      88                  for (k,v) in kw.items()}
# ---> 89         return f(*new_a, **new_kw)
#      90     return decorator.decorator(wrapper)
#      91
#
# /Users/Home/miniconda3/envs/carnd-term1/lib/python3.5/site-packages/moviepy/Clip.py in get_frame(self, t)
#      93                 return frame
#      94         else:
# ---> 95             return self.make_frame(t)
#      96
#      97     def fl(self, fun, apply_to=[] , keep_duration=True):
#
# /Users/Home/miniconda3/envs/carnd-term1/lib/python3.5/site-packages/moviepy/Clip.py in <lambda>(t)
#     134
#     135         #mf = copy(self.make_frame)
# --> 136         newclip = self.set_make_frame(lambda t: fun(self.get_frame, t))
#     137
#     138         if not keep_duration:
#
# /Users/Home/miniconda3/envs/carnd-term1/lib/python3.5/site-packages/moviepy/video/VideoClip.py in <lambda>(gf, t)
#     511         `get_frame(t)` by another frame,  `image_func(get_frame(t))`
#     512         """
# --> 513         return self.fl(lambda gf, t: image_func(gf(t)), apply_to)
#     514
#     515     # --------------------------------------------------------------
#
# <ipython-input-8-fc8941e246af> in process_image(image)
#       3     # TODO: put your pipeline here,
#       4     # you should return the final output (image where lines are drawn on lanes)
# ----> 5     result = houghInference(image)
#       6
#       7     return result
#
# <ipython-input-209-64f1d0547573> in houghInference(image)
#      59     min_line_length = 20 #minimum number of pixels making up a line
#      60     max_line_gap = 10    # maximum gap in pixels between connectable line segments
# ---> 61     line_image = hough_lines(masked_edges, rho, theta, threshold, min_line_length, max_line_gap)
#      62
#      63     # Create a "color" binary image to combine with line image
#
# <ipython-input-208-c741f40f8742> in hough_lines(img, rho, theta, threshold, min_line_len, max_line_gap)
#     150     lines = cv2.HoughLinesP(img, rho, theta, threshold, np.array([]), minLineLength=min_line_len, maxLineGap=max_line_gap)
#     151     line_img = np.zeros((img.shape[0], img.shape[1], 3), dtype=np.uint8)
# --> 152     draw_lines(line_img, lines)
#     153     return line_img
#     154
#
# <ipython-input-208-c741f40f8742> in draw_lines(img, lines)
#     136     lineR = create_FitLine(lineR_hist)
#     137     lineL = create_FitLine(lineL_hist)
# --> 138     intersect = get_intersection(lineR,lineL)
#     139     disp_fitLine(img,lineR,intersect)
#     140     disp_fitLine(img,lineL,intersect)
#
# <ipython-input-208-c741f40f8742> in get_intersection(line1, line2)
#      54     l1=np.insert(line1, 1, -1)
#      55     l2=np.insert(line2, 1, -1)
# ---> 56     x, y, z= np.cross(l1, l2)
#      57     return np.hstack([x, y]) / z
#      58
#
# /Users/Home/miniconda3/envs/carnd-term1/lib/python3.5/site-packages/numpy/core/numeric.py in cross(a, b, axisa, axisb, axisc, axis)
#    1831             multiply(a2, b1, out=cp0)
#    1832             negative(cp0, out=cp0)
# -> 1833             multiply(a2, b0, out=cp1)
#    1834             multiply(a0, b1, out=cp2)
#    1835             cp2 -= a1 * b0
#
# TypeError: unsupported operand type(s) for *: 'float' and 'NoneType'
#   6%|▋         | 44/682 [00:11<02:44,  3.87it/s]

# %%
HTML("""
<video width="960" height="540" controls>
  <source src="{0}">
</video>
""".format(yellow_output))

# %% [markdown]
# ## Writeup and Submission
#
# If you're satisfied with your video outputs, it's time to make the report writeup in a pdf or markdown file. Once you have this Ipython notebook ready along with the writeup, it's time to submit for review! Here is a [link](https://github.com/udacity/CarND-LaneLines-P1/blob/master/writeup_template.md) to the writeup template file.

# %% [markdown]
# ## Optional Challenge
#
# Try your lane finding pipeline on the video below.  Does it still work?  Can you figure out a way to make it more robust?  If you're up for the challenge, modify your pipeline so it works with this video and submit it along with the rest of your project!

# %%
challenge_output = 'test_videos_output/challenge.mp4'
clip2 = VideoFileClip('test_videos/challenge.mp4')
challenge_clip = clip2.fl_image(process_image)
# %time challenge_clip.write_videofile(challenge_output, audio=False)
# Out:
# LineR: (array([-0.68580234], dtype=float32), array([ 871.62640381], dtype=float32)) PLineR: (array([-0.68580234], dtype=float32), array([ 871.62640381], dtype=float32))
# LineL: (array([ 0.63003731], dtype=float32), array([ 2.4855957], dtype=float32)) PLineL: (array([ 0.63003731], dtype=float32), array([ 2.4855957], dtype=float32))
# [MoviePy] >>>> Building video test_videos_output/challenge.mp4
# [MoviePy] Writing video test_videos_output/challenge.mp4
#   0%|          | 0/251 [00:00<?, ?it/s]
#
#
#
#
#   1%|          | 2/251 [00:00<00:14, 17.47it/s]
# LineR: (array([-0.68580234], dtype=float32), array([ 871.62640381], dtype=float32)) PLineR: (array([-0.68580234], dtype=float32), array([ 871.62640381], dtype=float32))
# LineL: (array([ 0.63003731], dtype=float32), array([ 2.4855957], dtype=float32)) PLineL: (array([ 0.63003731], dtype=float32), array([ 2.4855957], dtype=float32))
# LineR: (array([-0.68181878], dtype=float32), array([ 868.81768799], dtype=float32)) PLineR: (array([-0.68181878], dtype=float32), array([ 868.81768799], dtype=float32))
# LineL: (array([ 0.62840819], dtype=float32), array([ 3.81934619], dtype=float32)) PLineL: (array([ 0.62840819], dtype=float32), array([ 3.81934619], dtype=float32))
# LineR: (array([-0.68280447], dtype=float32), array([ 868.69287109], dtype=float32)) PLineR: (array([-0.68280447], dtype=float32), array([ 868.69287109], dtype=float32))
# LineL: (array([ 0.6247977], dtype=float32), array([ 6.61255646], dtype=float32)) PLineL: (array([ 0.6247977], dtype=float32), array([ 6.61255646], dtype=float32))
#   2%|▏         | 4/251 [00:00<00:13, 17.93it/s]
# LineR: (array([-0.68594545], dtype=float32), array([ 869.88494873], dtype=float32)) PLineR: (array([-0.68594545], dtype=float32), array([ 869.88494873], dtype=float32))
# LineL: (array([ 0.62363493], dtype=float32), array([ 6.83729267], dtype=float32)) PLineL: (array([ 0.62363493], dtype=float32), array([ 6.83729267], dtype=float32))
#   2%|▏         | 6/251 [00:00<00:13, 18.18it/s]
# LineR: (array([-0.6837303], dtype=float32), array([ 869.0401001], dtype=float32)) PLineR: (array([-0.6837303], dtype=float32), array([ 869.0401001], dtype=float32))
# LineL: (array([ 0.62617725], dtype=float32), array([ 4.49635315], dtype=float32)) PLineL: (array([ 0.62617725], dtype=float32), array([ 4.49635315], dtype=float32))
# LineR: (array([-0.68433011], dtype=float32), array([ 869.68798828], dtype=float32)) PLineR: (array([-0.68433011], dtype=float32), array([ 869.68798828], dtype=float32))
# LineL: (array([ 0.62675983], dtype=float32), array([ 3.71973753], dtype=float32)) PLineL: (array([ 0.62675983], dtype=float32), array([ 3.71973753], dtype=float32))
# LineR: (array([-0.68640435], dtype=float32), array([ 870.99414062], dtype=float32)) PLineR: (array([-0.68640435], dtype=float32), array([ 870.99414062], dtype=float32))
# LineL: (array([ 0.62414086], dtype=float32), array([ 5.49577713], dtype=float32)) PLineL: (array([ 0.62414086], dtype=float32), array([ 5.49577713], dtype=float32))
# LineR:
#  (array([-0.68783164], dtype=float32), array([ 871.98132324], dtype=float32)) PLineR: (array([-0.68783164], dtype=float32), array([ 871.98132324], dtype=float32))
# LineL: (array([ 0.62279266], dtype=float32), array([ 6.70810604], dtype=float32)) PLineL: (array([ 0.62279266], dtype=float32), array([ 6.70810604], dtype=float32))
# LineR:
#   4%|▎         | 9/251 [00:00<00:12, 18.63it/s]
#
#
#
#
#   4%|▍         | 11/251 [00:00<00:12, 18.68it/s]
#  (array([-0.68811488], dtype=float32), array([ 872.07165527], dtype=float32)) PLineR: (array([-0.68811488], dtype=float32), array([ 872.07165527], dtype=float32))
# LineL: (array([ 0.62602776], dtype=float32), array([ 4.02919483], dtype=float32)) PLineL: (array([ 0.62602776], dtype=float32), array([ 4.02919483], dtype=float32))
# LineR: (array([-0.69055003], dtype=float32), array([ 873.46289062], dtype=float32)) PLineR: (array([-0.69055003], dtype=float32), array([ 873.46289062], dtype=float32))
# LineL: (array([ 0.6282714], dtype=float32), array([ 1.93448067], dtype=float32)) PLineL: (array([ 0.6282714], dtype=float32), array([ 1.93448067], dtype=float32))
# LineR: (array([-0.69314712], dtype=float32), array([ 874.80889893], dtype=float32)) PLineR: (array([-0.69314712], dtype=float32), array([ 874.80889893], dtype=float32))
# LineL: (array([ 0.63070077], dtype=float32), array([ 0.08266958], dtype=float32)) PLineL: (array([ 0.63070077], dtype=float32), array([ 0.08266958], dtype=float32))
# LineR: (array([-0.69276088], dtype=float32), array([ 874.65039062], dtype=float32)) PLineR: (array([-0.69276088], dtype=float32), array([ 874.65039062], dtype=float32))
# LineL: (array([ 0.63215244], dtype=float32), array([-1.14935064], dtype=float32)) PLineL: (array([ 0.63215244], dtype=float32), array([-1.14935064], dtype=float32))
# LineR:
#   5%|▌         | 13/251 [00:00<00:12, 18.91it/s]
#
#
#
#
#   6%|▌         | 15/251 [00:00<00:12, 18.73it/s]
#  (array([-0.69462138], dtype=float32), array([ 875.63879395], dtype=float32)) PLineR: (array([-0.69462138], dtype=float32), array([ 875.63879395], dtype=float32))
# LineL: (array([ 0.63363886], dtype=float32), array([-3.04090166], dtype=float32)) PLineL: (array([ 0.63363886], dtype=float32), array([-3.04090166], dtype=float32))
# LineR: (array([-0.69390756], dtype=float32), array([ 875.3793335], dtype=float32)) PLineR: (array([-0.69390756], dtype=float32), array([ 875.3793335], dtype=float32))
# LineL: (array([ 0.6340431], dtype=float32), array([-3.77721], dtype=float32)) PLineL: (array([ 0.6340431], dtype=float32), array([-3.77721], dtype=float32))
# LineR: (array([-0.69513828], dtype=float32), array([ 876.02825928], dtype=float32)) PLineR: (array([-0.69513828], dtype=float32), array([ 876.02825928], dtype=float32))
# LineL: (array([ 0.63303441], dtype=float32), array([-2.85934043], dtype=float32)) PLineL: (array([ 0.63303441], dtype=float32), array([-2.85934043], dtype=float32))
# LineR: (array([-0.69580346], dtype=float32), array([ 876.41662598], dtype=float32)) PLineR: (array([-0.69580346], dtype=float32), array([ 876.41662598], dtype=float32))
# LineL: (array([ 0.63332242], dtype=float32), array([-2.98323131], dtype=float32)) PLineL: (array([ 0.63332242], dtype=float32), array([-2.98323131], dtype=float32))
#   7%|▋         | 17/251 [00:00<00:12, 18.68it/s]
#
#
#
#
#   8%|▊         | 19/251 [00:01<00:12, 18.56it/s]
# LineR: (array([-0.69734019], dtype=float32), array([ 877.23419189], dtype=float32)) PLineR: (array([-0.69734019], dtype=float32), array([ 877.23419189], dtype=float32))
# LineL: (array([ 0.63444734], dtype=float32), array([-3.7978549], dtype=float32)) PLineL: (array([ 0.63444734], dtype=float32), array([-3.7978549], dtype=float32))
# LineR: (array([-0.69835544], dtype=float32), array([ 877.76190186], dtype=float32)) PLineR: (array([-0.69835544], dtype=float32), array([ 877.76190186], dtype=float32))
# LineL: (array([ 0.63592917], dtype=float32), array([-4.86818504], dtype=float32)) PLineL: (array([ 0.63592917], dtype=float32), array([-4.86818504], dtype=float32))
# LineR: (array([-0.6995784], dtype=float32), array([ 878.29052734], dtype=float32)) PLineR: (array([-0.6995784], dtype=float32), array([ 878.29052734], dtype=float32))
# LineL: (array([ 0.63575202], dtype=float32), array([-4.61198568], dtype=float32)) PLineL: (array([ 0.63575202], dtype=float32), array([-4.61198568], dtype=float32))
# LineR: (array([-0.70056754], dtype=float32), array([ 878.80133057], dtype=float32)) PLineR: (array([-0.70056754], dtype=float32), array([ 878.80133057], dtype=float32))
# LineL: (array([ 0.63596797], dtype=float32), array([-4.70370245], dtype=float32)) PLineL: (array([ 0.63596797], dtype=float32), array([-4.70370245], dtype=float32))
#   8%|▊         | 21/251 [00:01<00:12, 18.64it/s]
#
#
#
#
#   9%|▉         | 23/251 [00:01<00:12, 18.78it/s]
# LineR: (array([-0.70170504], dtype=float32), array([ 879.22949219], dtype=float32)) PLineR: (array([-0.70170504], dtype=float32), array([ 879.22949219], dtype=float32))
# LineL: (array([ 0.63687205], dtype=float32), array([-5.25258112], dtype=float32)) PLineL: (array([ 0.63687205], dtype=float32), array([-5.25258112], dtype=float32))
# LineR: (array([-0.70165902], dtype=float32), array([ 879.15795898], dtype=float32)) PLineR: (array([-0.70165902], dtype=float32), array([ 879.15795898], dtype=float32))
# LineL: (array([ 0.63630038], dtype=float32), array([-4.56186152], dtype=float32)) PLineL: (array([ 0.63630038], dtype=float32), array([-4.56186152], dtype=float32))
# LineR: (array([-0.7022078], dtype=float32), array([ 879.27740479], dtype=float32)) PLineR: (array([-0.7022078], dtype=float32), array([ 879.27740479], dtype=float32))
# LineL: (array([ 0.63583857], dtype=float32), array([-4.20351171], dtype=float32)) PLineL: (array([ 0.63583857], dtype=float32), array([-4.20351171], dtype=float32))
# LineR: (array([-0.70326132], dtype=float32), array([ 879.72241211], dtype=float32)) PLineR: (array([-0.70326132], dtype=float32), array([ 879.72241211], dtype=float32))
# LineL: (array([ 0.63496852], dtype=float32), array([-3.19647217], dtype=float32)) PLineL: (array([ 0.63496852], dtype=float32), array([-3.19647217], dtype=float32))
# LineR:
#  10%|▉         | 25/251 [00:01<00:11, 18.96it/s]
#
#
#
#
#  11%|█         | 27/251 [00:01<00:11, 19.05it/s]
#  (array([-0.70309538], dtype=float32), array([ 879.4597168], dtype=float32)) PLineR: (array([-0.70309538], dtype=float32), array([ 879.4597168], dtype=float32))
# LineL: (array([ 0.63495922], dtype=float32), array([-3.13515449], dtype=float32)) PLineL: (array([ 0.63495922], dtype=float32), array([-3.13515449], dtype=float32))
# LineR: (array([-0.70356411], dtype=float32), array([ 879.57952881], dtype=float32)) PLineR: (array([-0.70356411], dtype=float32), array([ 879.57952881], dtype=float32))
# LineL: (array([ 0.63428843], dtype=float32), array([-2.53111362], dtype=float32)) PLineL: (array([ 0.63428843], dtype=float32), array([-2.53111362], dtype=float32))
# LineR: (array([-0.70496428], dtype=float32), array([ 880.26300049], dtype=float32)) PLineR: (array([-0.70496428], dtype=float32), array([ 880.26300049], dtype=float32))
# LineL: (array([ 0.63430393], dtype=float32), array([-2.44745874], dtype=float32)) PLineL: (array([ 0.63430393], dtype=float32), array([-2.44745874], dtype=float32))
# LineR: (array([-0.70619631], dtype=float32), array([ 880.72003174], dtype=float32)) PLineR: (array([-0.70619631], dtype=float32), array([ 880.72003174], dtype=float32))
# LineL: (array([ 0.63496274], dtype=float32), array([-2.98022604], dtype=float32)) PLineL: (array([ 0.63496274], dtype=float32), array([-2.98022604], dtype=float32))
#  12%|█▏        | 29/251 [00:01<00:11, 18.75it/s]
#
#
#
#
#  12%|█▏        | 31/251 [00:01<00:11, 18.88it/s]
# LineR: (array([-0.70666033], dtype=float32), array([ 880.86730957], dtype=float32)) PLineR: (array([-0.70666033], dtype=float32), array([ 880.86730957], dtype=float32))
# LineL: (array([ 0.63468397], dtype=float32), array([-2.78098059], dtype=float32)) PLineL: (array([ 0.63468397], dtype=float32), array([-2.78098059], dtype=float32))
# LineR: (array([-0.70611542], dtype=float32), array([ 880.53161621], dtype=float32)) PLineR: (array([-0.70611542], dtype=float32), array([ 880.53161621], dtype=float32))
# LineL: (array([ 0.63594782], dtype=float32), array([-3.72509503], dtype=float32)) PLineL: (array([ 0.63594782], dtype=float32), array([-3.72509503], dtype=float32))
# LineR: (array([-0.70631224], dtype=float32), array([ 880.3927002], dtype=float32)) PLineR: (array([-0.70631224], dtype=float32), array([ 880.3927002], dtype=float32))
# LineL: (array([ 0.63586134], dtype=float32), array([-3.56762052], dtype=float32)) PLineL: (array([ 0.63586134], dtype=float32), array([-3.56762052], dtype=float32))
# LineR: (array([-0.70607644], dtype=float32), array([ 880.27832031], dtype=float32)) PLineR: (array([-0.70607644], dtype=float32), array([ 880.27832031], dtype=float32))
# LineL: (array([ 0.6363138], dtype=float32), array([-3.82194495], dtype=float32)) PLineL: (array([ 0.6363138], dtype=float32), array([-3.82194495], dtype=float32))
#  13%|█▎        | 33/251 [00:01<00:11, 18.62it/s]
#
#
#
#
#  14%|█▍        | 35/251 [00:01<00:11, 18.56it/s]
# LineR: (array([-0.70603859], dtype=float32), array([ 880.277771], dtype=float32)) PLineR: (array([-0.70603859], dtype=float32), array([ 880.277771], dtype=float32))
# LineL: (array([ 0.63650626], dtype=float32), array([-3.78306389], dtype=float32)) PLineL: (array([ 0.63650626], dtype=float32), array([-3.78306389], dtype=float32))
# LineR: (array([-0.70601279], dtype=float32), array([ 880.10522461], dtype=float32)) PLineR: (array([-0.70601279], dtype=float32), array([ 880.10522461], dtype=float32))
# LineL: (array([ 0.63702464], dtype=float32), array([-4.10902643], dtype=float32)) PLineL: (array([ 0.63702464], dtype=float32), array([-4.10902643], dtype=float32))
# LineR: (array([-0.70681685], dtype=float32), array([ 880.3548584], dtype=float32)) PLineR: (array([-0.70681685], dtype=float32), array([ 880.3548584], dtype=float32))
# LineL: (array([ 0.63670069], dtype=float32), array([-3.73718929], dtype=float32)) PLineL: (array([ 0.63670069], dtype=float32), array([-3.73718929], dtype=float32))
# LineR: (array([-0.70626932], dtype=float32), array([ 880.07678223], dtype=float32)) PLineR: (array([-0.70626932], dtype=float32), array([ 880.07678223], dtype=float32))
# LineL: (array([ 0.6364885], dtype=float32), array([-3.37962127], dtype=float32)) PLineL: (array([ 0.6364885], dtype=float32), array([-3.37962127], dtype=float32))
#  15%|█▍        | 37/251 [00:01<00:11, 18.47it/s]
#
#
#
#
#  16%|█▌        | 39/251 [00:02<00:11, 18.54it/s]
# LineR: (array([-0.7061075], dtype=float32), array([ 879.94787598], dtype=float32)) PLineR: (array([-0.7061075], dtype=float32), array([ 879.94787598], dtype=float32))
# LineL: (array([ 0.63586426], dtype=float32), array([-2.8535552], dtype=float32)) PLineL: (array([ 0.63586426], dtype=float32), array([-2.8535552], dtype=float32))
# LineR: (array([-0.70530158], dtype=float32), array([ 879.51239014], dtype=float32)) PLineR: (array([-0.70530158], dtype=float32), array([ 879.51239014], dtype=float32))
# LineL: (array([ 0.63583028], dtype=float32), array([-2.60388684], dtype=float32)) PLineL: (array([ 0.63583028], dtype=float32), array([-2.60388684], dtype=float32))
# LineR: (array([-0.70458317], dtype=float32), array([ 879.15429688], dtype=float32)) PLineR: (array([-0.70458317], dtype=float32), array([ 879.15429688], dtype=float32))
# LineL: (array([ 0.63511312], dtype=float32), array([-2.08700514], dtype=float32)) PLineL: (array([ 0.63511312], dtype=float32), array([-2.08700514], dtype=float32))
# LineR: (array([-0.70449388], dtype=float32), array([ 878.97253418], dtype=float32)) PLineR: (array([-0.70449388], dtype=float32), array([ 878.97253418], dtype=float32))
# LineL: (array([ 0.63508683], dtype=float32), array([-2.10440421], dtype=float32)) PLineL: (array([ 0.63508683], dtype=float32), array([-2.10440421], dtype=float32))
#  16%|█▋        | 41/251 [00:02<00:11, 18.67it/s]
#
#
#
#
#  17%|█▋        | 43/251 [00:02<00:11, 18.35it/s]
# LineR: (array([-0.70328456], dtype=float32), array([ 878.42883301], dtype=float32)) PLineR: (array([-0.70328456], dtype=float32), array([ 878.42883301], dtype=float32))
# LineL: (array([ 0.63517737], dtype=float32), array([-2.13300347], dtype=float32)) PLineL: (array([ 0.63517737], dtype=float32), array([-2.13300347], dtype=float32))
# LineR: (array([-0.70291787], dtype=float32), array([ 878.17370605], dtype=float32)) PLineR: (array([-0.70291787], dtype=float32), array([ 878.17370605], dtype=float32))
# LineL: (array([ 0.63498944], dtype=float32), array([-1.91048181], dtype=float32)) PLineL: (array([ 0.63498944], dtype=float32), array([-1.91048181], dtype=float32))
# LineR: (array([-0.70218295], dtype=float32), array([ 877.85620117], dtype=float32)) PLineR: (array([-0.70218295], dtype=float32), array([ 877.85620117], dtype=float32))
# LineL: (array([ 0.63520998], dtype=float32), array([-2.01946282], dtype=float32)) PLineL: (array([ 0.63520998], dtype=float32), array([-2.01946282], dtype=float32))
# LineR: (array([-0.70132864], dtype=float32), array([ 877.38665771], dtype=float32)) PLineR: (array([-0.70132864], dtype=float32), array([ 877.38665771], dtype=float32))
# LineL: (array([ 0.63531488], dtype=float32), array([-2.07643223], dtype=float32)) PLineL: (array([ 0.63531488], dtype=float32), array([-2.07643223], dtype=float32))
#  18%|█▊        | 45/251 [00:02<00:11, 18.01it/s]
#
#
#
#
#  19%|█▊        | 47/251 [00:02<00:11, 18.27it/s]
# LineR: (array([-0.7010631], dtype=float32), array([ 877.23986816], dtype=float32)) PLineR: (array([-0.7010631], dtype=float32), array([ 877.23986816], dtype=float32))
# LineL: (array([ 0.63526779], dtype=float32), array([-1.95746911], dtype=float32)) PLineL: (array([ 0.63526779], dtype=float32), array([-1.95746911], dtype=float32))
# LineR: (array([-0.70051056], dtype=float32), array([ 877.02093506], dtype=float32)) PLineR: (array([-0.70051056], dtype=float32), array([ 877.02093506], dtype=float32))
# LineL: (array([ 0.63526779], dtype=float32), array([-1.95746911], dtype=float32)) PLineL: (array([ 0.63526779], dtype=float32), array([-1.95746911], dtype=float32))
# LineR: (array([-0.70110637], dtype=float32), array([ 877.40655518], dtype=float32)) PLineR: (array([-0.70110637], dtype=float32), array([ 877.40655518], dtype=float32))
# LineL: (array([ 0.63524055], dtype=float32), array([-1.86770499], dtype=float32)) PLineL: (array([ 0.63524055], dtype=float32), array([-1.86770499], dtype=float32))
# LineR: (array([-0.70133162], dtype=float32), array([ 877.61572266], dtype=float32)) PLineR: (array([-0.70133162], dtype=float32), array([ 877.61572266], dtype=float32))
# LineL: (array([ 0.63477027], dtype=float32), array([-1.49146736], dtype=float32)) PLineL: (array([ 0.63477027], dtype=float32), array([-1.49146736], dtype=float32))
#  20%|█▉        | 49/251 [00:02<00:11, 18.10it/s]
#
#
#
#
#  20%|██        | 51/251 [00:02<00:11, 17.93it/s]
# LineR: (array([-0.70127922], dtype=float32), array([ 877.56591797], dtype=float32)) PLineR: (array([-0.70127922], dtype=float32), array([ 877.56591797], dtype=float32))
# LineL: (array([ 0.63496178], dtype=float32), array([-1.68120074], dtype=float32)) PLineL: (array([ 0.63496178], dtype=float32), array([-1.68120074], dtype=float32))
# LineR: (array([-0.70141464], dtype=float32), array([ 877.61206055], dtype=float32)) PLineR: (array([-0.70141464], dtype=float32), array([ 877.61206055], dtype=float32))
# LineL: (array([ 0.6345703], dtype=float32), array([-1.37988508], dtype=float32)) PLineL: (array([ 0.6345703], dtype=float32), array([-1.37988508], dtype=float32))
# LineR: (array([-0.7010619], dtype=float32), array([ 877.50854492], dtype=float32)) PLineR: (array([-0.7010619], dtype=float32), array([ 877.50854492], dtype=float32))
# LineL: (array([ 0.63459152], dtype=float32), array([-1.3591727], dtype=float32)) PLineL: (array([ 0.63459152], dtype=float32), array([-1.3591727], dtype=float32))
# LineR: (array([-0.70139682], dtype=float32), array([ 877.74279785], dtype=float32)) PLineR: (array([-0.70139682], dtype=float32), array([ 877.74279785], dtype=float32))
# LineL: (array([ 0.63577843], dtype=float32), array([-2.34045815], dtype=float32)) PLineL: (array([ 0.63577843], dtype=float32), array([-2.34045815], dtype=float32))
#  21%|██        | 53/251 [00:02<00:11, 17.58it/s]
#
#
#
#
#  22%|██▏       | 55/251 [00:02<00:11, 17.01it/s]
# LineR: (array([-0.70163047], dtype=float32), array([ 877.92718506], dtype=float32)) PLineR: (array([-0.70163047], dtype=float32), array([ 877.92718506], dtype=float32))
# LineL: (array([ 0.63539135], dtype=float32), array([-2.04780197], dtype=float32)) PLineL: (array([ 0.63539135], dtype=float32), array([-2.04780197], dtype=float32))
# LineR: (array([-0.70161867], dtype=float32), array([ 877.97143555], dtype=float32)) PLineR: (array([-0.70161867], dtype=float32), array([ 877.97143555], dtype=float32))
# LineL: (array([ 0.63573086], dtype=float32), array([-2.29914665], dtype=float32)) PLineL: (array([ 0.63573086], dtype=float32), array([-2.29914665], dtype=float32))
# LineR: (array([-0.70158225], dtype=float32), array([ 878.00665283], dtype=float32)) PLineR: (array([-0.70158225], dtype=float32), array([ 878.00665283], dtype=float32))
# LineL: (array([ 0.63599819], dtype=float32), array([-2.61411357], dtype=float32)) PLineL: (array([ 0.63599819], dtype=float32), array([-2.61411357], dtype=float32))
# LineR:
#  23%|██▎       | 57/251 [00:03<00:12, 15.75it/s]
#  (array([-0.70178264], dtype=float32), array([ 878.17633057], dtype=float32)) PLineR: (array([-0.70178264], dtype=float32), array([ 878.17633057], dtype=float32))
# LineL: (array([ 0.63635558], dtype=float32), array([-2.82512331], dtype=float32)) PLineL: (array([ 0.63635558], dtype=float32), array([-2.82512331], dtype=float32))
# LineR: (array([-0.70195699], dtype=float32), array([ 878.25732422], dtype=float32)) PLineR: (array([-0.70195699], dtype=float32), array([ 878.25732422], dtype=float32))
# LineL: (array([ 0.63670421], dtype=float32), array([-3.09832788], dtype=float32)) PLineL: (array([ 0.63670421], dtype=float32), array([-3.09832788], dtype=float32))
# LineR: (array([-0.70236707], dtype=float32), array([ 878.39465332], dtype=float32)) PLineR: (array([-0.70236707], dtype=float32), array([ 878.39465332], dtype=float32))
# LineL: (array([ 0.6365701], dtype=float32), array([-2.96502733], dtype=float32)) PLineL: (array([ 0.6365701], dtype=float32), array([-2.96502733], dtype=float32))
#  24%|██▎       | 59/251 [00:03<00:12, 15.31it/s]
#
#
#
#
#  24%|██▍       | 61/251 [00:03<00:12, 15.00it/s]
# LineR: (array([-0.70247382], dtype=float32), array([ 878.47137451], dtype=float32)) PLineR: (array([-0.70247382], dtype=float32), array([ 878.47137451], dtype=float32))
# LineL: (array([ 0.63617414], dtype=float32), array([-2.6506815], dtype=float32)) PLineL: (array([ 0.63617414], dtype=float32), array([-2.6506815], dtype=float32))
# LineR: (array([-0.70244479], dtype=float32), array([ 878.48547363], dtype=float32)) PLineR: (array([-0.70244479], dtype=float32), array([ 878.48547363], dtype=float32))
# LineL: (array([ 0.63620079], dtype=float32), array([-2.6693418], dtype=float32)) PLineL: (array([ 0.63620079], dtype=float32), array([-2.6693418], dtype=float32))
# LineR: (array([-0.70248878], dtype=float32), array([ 878.53765869], dtype=float32)) PLineR: (array([-0.70248878], dtype=float32), array([ 878.53765869], dtype=float32))
# LineL: (array([ 0.63657975], dtype=float32), array([-3.00216746], dtype=float32)) PLineL: (array([ 0.63657975], dtype=float32), array([-3.00216746], dtype=float32))
#  25%|██▌       | 63/251 [00:03<00:12, 15.10it/s]
# LineR: (array([-0.7022469], dtype=float32), array([ 878.39642334], dtype=float32)) PLineR: (array([-0.7022469], dtype=float32), array([ 878.39642334], dtype=float32))
# LineL: (array([ 0.63666618], dtype=float32), array([-3.10936427], dtype=float32)) PLineL: (array([ 0.63666618], dtype=float32), array([-3.10936427], dtype=float32))
# LineR: (array([-0.70212674], dtype=float32), array([ 878.34240723], dtype=float32)) PLineR: (array([-0.70212674], dtype=float32), array([ 878.34240723], dtype=float32))
# LineL: (array([ 0.63643378], dtype=float32), array([-2.95518088], dtype=float32)) PLineL: (array([ 0.63643378], dtype=float32), array([-2.95518088], dtype=float32))
# LineR: (array([-0.70187414], dtype=float32), array([ 878.19934082], dtype=float32)) PLineR: (array([-0.70187414], dtype=float32), array([ 878.19934082], dtype=float32))
# LineL: (array([ 0.63652116], dtype=float32), array([-3.03162622], dtype=float32)) PLineL: (array([ 0.63652116], dtype=float32), array([-3.03162622], dtype=float32))
#  26%|██▌       | 65/251 [00:03<00:12, 14.82it/s]
#
#
#
#
#  27%|██▋       | 67/251 [00:03<00:12, 14.74it/s]
# LineR: (array([-0.70182329], dtype=float32), array([ 878.1762085], dtype=float32)) PLineR: (array([-0.70182329], dtype=float32), array([ 878.1762085], dtype=float32))
# LineL: (array([ 0.63634557], dtype=float32), array([-2.9236784], dtype=float32)) PLineL: (array([ 0.63634557], dtype=float32), array([-2.9236784], dtype=float32))
# LineR: (array([-0.70148081], dtype=float32), array([ 878.01611328], dtype=float32)) PLineR: (array([-0.70148081], dtype=float32), array([ 878.01611328], dtype=float32))
# LineL: (array([ 0.63663781], dtype=float32), array([-3.21099544], dtype=float32)) PLineL: (array([ 0.63663781], dtype=float32), array([-3.21099544], dtype=float32))
# LineR: (array([-0.70170778], dtype=float32), array([ 878.18438721], dtype=float32)) PLineR: (array([-0.70170778], dtype=float32), array([ 878.18438721], dtype=float32))
# LineL: (array([ 0.6369229], dtype=float32), array([-3.46280122], dtype=float32)) PLineL: (array([ 0.6369229], dtype=float32), array([-3.46280122], dtype=float32))
# LineR:
#  27%|██▋       | 69/251 [00:03<00:11, 15.30it/s]
#
#
#
#
#  28%|██▊       | 71/251 [00:04<00:11, 15.61it/s]
# (array([-0.70211244], dtype=float32), array([ 878.44854736], dtype=float32)) PLineR: (array([-0.70211244], dtype=float32), array([ 878.44854736], dtype=float32))
# LineL: (array([ 0.63688159], dtype=float32), array([-3.45690727], dtype=float32)) PLineL: (array([ 0.63688159], dtype=float32), array([-3.45690727], dtype=float32))
# LineR: (array([-0.70207071], dtype=float32), array([ 878.46844482], dtype=float32)) PLineR: (array([-0.70207071], dtype=float32), array([ 878.46844482], dtype=float32))
# LineL: (array([ 0.63662201], dtype=float32), array([-3.25859404], dtype=float32)) PLineL: (array([ 0.63662201], dtype=float32), array([-3.25859404], dtype=float32))
# LineR: (array([-0.70203292], dtype=float32), array([ 878.48590088], dtype=float32)) PLineR: (array([-0.70203292], dtype=float32), array([ 878.48590088], dtype=float32))
# LineL: (array([ 0.63668841], dtype=float32), array([-3.41907215], dtype=float32)) PLineL: (array([ 0.63668841], dtype=float32), array([-3.41907215], dtype=float32))
# LineR: (array([-0.70204216], dtype=float32), array([ 878.59057617], dtype=float32)) PLineR: (array([-0.70204216], dtype=float32), array([ 878.59057617], dtype=float32))
# LineL: (array([ 0.63692284], dtype=float32), array([-3.67589307], dtype=float32)) PLineL: (array([ 0.63692284], dtype=float32), array([-3.67589307], dtype=float32))
#  29%|██▉       | 73/251 [00:04<00:11, 15.66it/s]
# LineR: (array([-0.70228767], dtype=float32), array([ 878.85430908], dtype=float32)) PLineR: (array([-0.70228767], dtype=float32), array([ 878.85430908], dtype=float32))
# LineL: (array([ 0.6367715], dtype=float32), array([-3.66230822], dtype=float32)) PLineL: (array([ 0.6367715], dtype=float32), array([-3.66230822], dtype=float32))
# LineR: (array([-0.70190752], dtype=float32), array([ 878.73956299], dtype=float32)) PLineR: (array([-0.70190752], dtype=float32), array([ 878.73956299], dtype=float32))
# LineL: (array([ 0.63656855], dtype=float32), array([-3.57847619], dtype=float32)) PLineL: (array([ 0.63656855], dtype=float32), array([-3.57847619], dtype=float32))
# LineR: (array([-0.70210862], dtype=float32), array([ 878.90332031], dtype=float32)) PLineR: (array([-0.70210862], dtype=float32), array([ 878.90332031], dtype=float32))
# LineL: (array([ 0.63665903], dtype=float32), array([-3.74150944], dtype=float32)) PLineL: (array([ 0.63665903], dtype=float32), array([-3.74150944], dtype=float32))
# LineR: (array([-0.70238262], dtype=float32), array([ 879.14892578], dtype=float32)) PLineR: (array([-0.70238262], dtype=float32), array([ 879.14892578], dtype=float32))
# LineL: (array([ 0.63636291], dtype=float32), array([-3.56912994], dtype=float32)) PLineL: (array([ 0.63636291], dtype=float32), array([-3.56912994], dtype=float32))
#  30%|██▉       | 75/251 [00:04<00:11, 15.66it/s]
#
#
#
#
#  31%|███       | 77/251 [00:04<00:11, 15.76it/s]
# LineR: (array([-0.70228052], dtype=float32), array([ 879.04211426], dtype=float32)) PLineR: (array([-0.70228052], dtype=float32), array([ 879.04211426], dtype=float32))
# LineL: (array([ 0.63645536], dtype=float32), array([-3.69963312], dtype=float32)) PLineL: (array([ 0.63645536], dtype=float32), array([-3.69963312], dtype=float32))
# LineR: (array([-0.70260394], dtype=float32), array([ 879.35925293], dtype=float32)) PLineR: (array([-0.70260394], dtype=float32), array([ 879.35925293], dtype=float32))
# LineL: (array([ 0.63645536], dtype=float32), array([-3.69963312], dtype=float32)) PLineL: (array([ 0.63645536], dtype=float32), array([-3.69963312], dtype=float32))
# LineR: (array([-0.70295751], dtype=float32), array([ 879.6776123], dtype=float32)) PLineR: (array([-0.70295751], dtype=float32), array([ 879.6776123], dtype=float32))
# LineL: (array([ 0.63645536], dtype=float32), array([-3.69963312], dtype=float32)) PLineL: (array([ 0.63645536], dtype=float32), array([-3.69963312], dtype=float32))
# LineR:
#  31%|███▏      | 79/251 [00:04<00:11, 15.26it/s]
#
#
#
#
#  32%|███▏      | 81/251 [00:04<00:11, 14.89it/s]
#  (array([-0.70338672], dtype=float32), array([ 879.99023438], dtype=float32)) PLineR: (array([-0.70338672], dtype=float32), array([ 879.99023438], dtype=float32))
# LineL: (array([ 0.63645536], dtype=float32), array([-3.69963312], dtype=float32)) PLineL: (array([ 0.63645536], dtype=float32), array([-3.69963312], dtype=float32))
# LineR: (array([-0.70363778], dtype=float32), array([ 880.24383545], dtype=float32)) PLineR: (array([-0.70363778], dtype=float32), array([ 880.24383545], dtype=float32))
# LineL: (array([ 0.63607472], dtype=float32), array([-3.45724535], dtype=float32)) PLineL: (array([ 0.63607472], dtype=float32), array([-3.45724535], dtype=float32))
# LineR: (array([-0.704355], dtype=float32), array([ 880.72790527], dtype=float32)) PLineR: (array([-0.704355], dtype=float32), array([ 880.72790527], dtype=float32))
# LineL: (array([ 0.63572371], dtype=float32), array([-3.22117114], dtype=float32)) PLineL: (array([ 0.63572371], dtype=float32), array([-3.22117114], dtype=float32))
# LineR:
#  33%|███▎      | 83/251 [00:04<00:11, 14.76it/s]
#  (array([-0.70479494], dtype=float32), array([ 881.1282959], dtype=float32)) PLineR: (array([-0.70479494], dtype=float32), array([ 881.1282959], dtype=float32))
# LineL: (array([ 0.63551265], dtype=float32), array([-3.15206647], dtype=float32)) PLineL: (array([ 0.63551265], dtype=float32), array([-3.15206647], dtype=float32))
# LineR: (array([-0.70540017], dtype=float32), array([ 881.54211426], dtype=float32)) PLineR: (array([-0.70540017], dtype=float32), array([ 881.54211426], dtype=float32))
# LineL: (array([ 0.63538122], dtype=float32), array([-3.1126647], dtype=float32)) PLineL: (array([ 0.63538122], dtype=float32), array([-3.1126647], dtype=float32))
# LineR: (array([-0.70553023], dtype=float32), array([ 881.69042969], dtype=float32)) PLineR: (array([-0.70553023], dtype=float32), array([ 881.69042969], dtype=float32))
# LineL: (array([ 0.63538122], dtype=float32), array([-3.1126647], dtype=float32)) PLineL: (array([ 0.63538122], dtype=float32), array([-3.1126647], dtype=float32))
# LineR: (array([-0.70608687], dtype=float32), array([ 882.07342529], dtype=float32)) PLineR: (array([-0.70608687], dtype=float32), array([ 882.07342529], dtype=float32))
# LineL: (array([ 0.63538122], dtype=float32), array([-3.1126647], dtype=float32)) PLineL: (array([ 0.63538122], dtype=float32), array([-3.1126647], dtype=float32))
#  34%|███▍      | 85/251 [00:05<00:11, 14.97it/s]
#
#
#
#
#  35%|███▍      | 87/251 [00:05<00:10, 15.04it/s]
# LineR: (array([-0.70638609], dtype=float32), array([ 882.34753418], dtype=float32)) PLineR: (array([-0.70638609], dtype=float32), array([ 882.34753418], dtype=float32))
# LineL: (array([ 0.63563883], dtype=float32), array([-3.31652164], dtype=float32)) PLineL: (array([ 0.63563883], dtype=float32), array([-3.31652164], dtype=float32))
# LineR: (array([-0.70702219], dtype=float32), array([ 882.76947021], dtype=float32)) PLineR: (array([-0.70702219], dtype=float32), array([ 882.76947021], dtype=float32))
# LineL: (array([ 0.63532323], dtype=float32), array([-3.08095384], dtype=float32)) PLineL: (array([ 0.63532323], dtype=float32), array([-3.08095384], dtype=float32))
# LineR: (array([-0.70750809], dtype=float32), array([ 883.16912842], dtype=float32)) PLineR: (array([-0.70750809], dtype=float32), array([ 883.16912842], dtype=float32))
# LineL: (array([ 0.63532323], dtype=float32), array([-3.08095384], dtype=float32)) PLineL: (array([ 0.63532323], dtype=float32), array([-3.08095384], dtype=float32))
# LineR:
#  35%|███▌      | 89/251 [00:05<00:10, 14.81it/s]
#
#
#
#
#  36%|███▋      | 91/251 [00:05<00:10, 14.71it/s]
#  (array([-0.70799887], dtype=float32), array([ 883.5569458], dtype=float32)) PLineR: (array([-0.70799887], dtype=float32), array([ 883.5569458], dtype=float32))
# LineL: (array([ 0.63494784], dtype=float32), array([-2.83073139], dtype=float32)) PLineL: (array([ 0.63494784], dtype=float32), array([-2.83073139], dtype=float32))
# LineR: (array([-0.70809853], dtype=float32), array([ 883.79266357], dtype=float32)) PLineR: (array([-0.70809853], dtype=float32), array([ 883.79266357], dtype=float32))
# LineL: (array([ 0.63509208], dtype=float32), array([-2.96229887], dtype=float32)) PLineL: (array([ 0.63509208], dtype=float32), array([-2.96229887], dtype=float32))
# LineR: (array([-0.70838016], dtype=float32), array([ 884.09075928], dtype=float32)) PLineR: (array([-0.70838016], dtype=float32), array([ 884.09075928], dtype=float32))
# LineL: (array([ 0.63509208], dtype=float32), array([-2.96229887], dtype=float32)) PLineL: (array([ 0.63509208], dtype=float32), array([-2.96229887], dtype=float32))
#  37%|███▋      | 93/251 [00:05<00:10, 14.47it/s]
# LineR: (array([-0.70855182], dtype=float32), array([ 884.37121582], dtype=float32)) PLineR: (array([-0.70855182], dtype=float32), array([ 884.37121582], dtype=float32))
# LineL: (array([ 0.63509208], dtype=float32), array([-2.96229887], dtype=float32)) PLineL: (array([ 0.63509208], dtype=float32), array([-2.96229887], dtype=float32))
# LineR: (array([-0.70878667], dtype=float32), array([ 884.69348145], dtype=float32)) PLineR: (array([-0.70878667], dtype=float32), array([ 884.69348145], dtype=float32))
# LineL: (array([ 0.63478154], dtype=float32), array([-2.77399516], dtype=float32)) PLineL: (array([ 0.63478154], dtype=float32), array([-2.77399516], dtype=float32))
# LineR: (array([-0.70903313], dtype=float32), array([ 884.96716309], dtype=float32)) PLineR: (array([-0.70903313], dtype=float32), array([ 884.96716309], dtype=float32))
# LineL: (array([ 0.6350109], dtype=float32), array([-3.07466125], dtype=float32)) PLineL: (array([ 0.6350109], dtype=float32), array([-3.07466125], dtype=float32))
#  38%|███▊      | 95/251 [00:05<00:10, 14.25it/s]
#
#
#
#
#  39%|███▊      | 97/251 [00:05<00:10, 14.37it/s]
# LineR: (array([-0.70911187], dtype=float32), array([ 885.1328125], dtype=float32)) PLineR: (array([-0.70911187], dtype=float32), array([ 885.1328125], dtype=float32))
# LineL: (array([ 0.63482744], dtype=float32), array([-3.00319552], dtype=float32)) PLineL: (array([ 0.63482744], dtype=float32), array([-3.00319552], dtype=float32))
# LineR: (array([-0.70948333], dtype=float32), array([ 885.45306396], dtype=float32)) PLineR: (array([-0.70948333], dtype=float32), array([ 885.45306396], dtype=float32))
# LineL: (array([ 0.6347158], dtype=float32), array([-2.97332931], dtype=float32)) PLineL: (array([ 0.6347158], dtype=float32), array([-2.97332931], dtype=float32))
# LineR: (array([-0.70945466], dtype=float32), array([ 885.58288574], dtype=float32)) PLineR: (array([-0.70945466], dtype=float32), array([ 885.58288574], dtype=float32))
# LineL: (array([ 0.6347158], dtype=float32), array([-2.97332931], dtype=float32)) PLineL: (array([ 0.6347158], dtype=float32), array([-2.97332931], dtype=float32))
#  39%|███▉      | 99/251 [00:05<00:10, 14.38it/s]
# LineR: (array([-0.70973921], dtype=float32), array([ 885.89538574], dtype=float32)) PLineR: (array([-0.70973921], dtype=float32), array([ 885.89538574], dtype=float32))
# LineL: (array([ 0.63470745], dtype=float32), array([-2.81189585], dtype=float32)) PLineL: (array([ 0.63470745], dtype=float32), array([-2.81189585], dtype=float32))
# LineR: (array([-0.70986825], dtype=float32), array([ 886.06140137], dtype=float32)) PLineR: (array([-0.70986825], dtype=float32), array([ 886.06140137], dtype=float32))
# LineL: (array([ 0.63521069], dtype=float32), array([-3.32243085], dtype=float32)) PLineL: (array([ 0.63521069], dtype=float32), array([-3.32243085], dtype=float32))
# LineR: (array([-0.70977551], dtype=float32), array([ 886.1206665], dtype=float32)) PLineR: (array([-0.70977551], dtype=float32), array([ 886.1206665], dtype=float32))
# LineL: (array([ 0.63541549], dtype=float32), array([-3.46258974], dtype=float32)) PLineL: (array([ 0.63541549], dtype=float32), array([-3.46258974], dtype=float32))
# LineR:
#  40%|████      | 101/251 [00:06<00:10, 14.65it/s]
#
#
#
#
#  41%|████      | 103/251 [00:06<00:09, 15.00it/s]
#  (array([-0.70950311], dtype=float32), array([ 886.13623047], dtype=float32)) PLineR: (array([-0.70950311], dtype=float32), array([ 886.13623047], dtype=float32))
# LineL: (array([ 0.63541549], dtype=float32), array([-3.46258974], dtype=float32)) PLineL: (array([ 0.63541549], dtype=float32), array([-3.46258974], dtype=float32))
# LineR: (array([-0.70964241], dtype=float32), array([ 886.26947021], dtype=float32)) PLineR: (array([-0.70964241], dtype=float32), array([ 886.26947021], dtype=float32))
# LineL: (array([ 0.63541549], dtype=float32), array([-3.46258974], dtype=float32)) PLineL: (array([ 0.63541549], dtype=float32), array([-3.46258974], dtype=float32))
# LineR: (array([-0.70988661], dtype=float32), array([ 886.39538574], dtype=float32)) PLineR: (array([-0.70988661], dtype=float32), array([ 886.39538574], dtype=float32))
# LineL: (array([ 0.63551366], dtype=float32), array([-3.6082859], dtype=float32)) PLineL: (array([ 0.63551366], dtype=float32), array([-3.6082859], dtype=float32))
# LineR: (array([-0.70982605], dtype=float32), array([ 886.17700195], dtype=float32)) PLineR: (array([-0.70982605], dtype=float32), array([ 886.17700195], dtype=float32))
# LineL: (array([ 0.63529718], dtype=float32), array([-3.47850323], dtype=float32)) PLineL: (array([ 0.63529718], dtype=float32), array([-3.47850323], dtype=float32))
#  42%|████▏     | 105/251 [00:06<00:09, 15.05it/s]
#
#
#
#
#  43%|████▎     | 107/251 [00:06<00:09, 14.66it/s]
# LineR: (array([-0.70994312], dtype=float32), array([ 886.12237549], dtype=float32)) PLineR: (array([-0.70994312], dtype=float32), array([ 886.12237549], dtype=float32))
# LineL: (array([ 0.63533139], dtype=float32), array([-3.60749221], dtype=float32)) PLineL: (array([ 0.63533139], dtype=float32), array([-3.60749221], dtype=float32))
# LineR: (array([-0.70975387], dtype=float32), array([ 885.71203613], dtype=float32)) PLineR: (array([-0.70975387], dtype=float32), array([ 885.71203613], dtype=float32))
# LineL: (array([ 0.63543588], dtype=float32), array([-2.14099383], dtype=float32)) PLineL: (array([ 0.63543588], dtype=float32), array([-2.14099383], dtype=float32))
# LineR: (array([-0.70963401], dtype=float32), array([ 885.13409424], dtype=float32)) PLineR: (array([-0.70963401], dtype=float32), array([ 885.13409424], dtype=float32))
# LineL: (array([ 0.63511521], dtype=float32), array([-2.03874993], dtype=float32)) PLineL: (array([ 0.63511521], dtype=float32), array([-2.03874993], dtype=float32))
#  43%|████▎     | 109/251 [00:06<00:10, 13.70it/s]
# LineR: (array([-0.70923167], dtype=float32), array([ 884.75805664], dtype=float32)) PLineR: (array([-0.70923167], dtype=float32), array([ 884.75805664], dtype=float32))
# LineL: (array([ 0.635391], dtype=float32), array([-0.72927934], dtype=float32)) PLineL: (array([ 0.635391], dtype=float32), array([-0.72927934], dtype=float32))
# LineR: (array([-0.70889443], dtype=float32), array([ 884.46362305], dtype=float32)) PLineR: (array([-0.70889443], dtype=float32), array([ 884.46362305], dtype=float32))
# LineL: (array([ 0.63576984], dtype=float32), array([-0.84777862], dtype=float32)) PLineL: (array([ 0.63576984], dtype=float32), array([-0.84777862], dtype=float32))
# LineR: (array([-0.70841604], dtype=float32), array([ 884.32073975], dtype=float32)) PLineR: (array([-0.70841604], dtype=float32), array([ 884.32073975], dtype=float32))
# LineL: (array([ 0.63597178], dtype=float32), array([-0.90412712], dtype=float32)) PLineL: (array([ 0.63597178], dtype=float32), array([-0.90412712], dtype=float32))
#  44%|████▍     | 111/251 [00:06<00:10, 13.16it/s]
#
#
#
#
#  45%|████▌     | 113/251 [00:07<00:11, 12.29it/s]
# LineR: (array([-0.70788437], dtype=float32), array([ 884.85748291], dtype=float32)) PLineR: (array([-0.70788437], dtype=float32), array([ 884.85748291], dtype=float32))
# LineL: (array([ 0.63617617], dtype=float32), array([-1.09496617], dtype=float32)) PLineL: (array([ 0.63617617], dtype=float32), array([-1.09496617], dtype=float32))
# LineR: (array([-0.70790154], dtype=float32), array([ 884.6685791], dtype=float32)) PLineR: (array([-0.70790154], dtype=float32), array([ 884.6685791], dtype=float32))
# LineL: (array([ 0.63632071], dtype=float32), array([-0.6019026], dtype=float32)) PLineL: (array([ 0.63632071], dtype=float32), array([-0.6019026], dtype=float32))
# LineR: (array([-0.70799732], dtype=float32), array([ 884.71154785], dtype=float32)) PLineR: (array([-0.70799732], dtype=float32), array([ 884.71154785], dtype=float32))
# LineL: (array([ 0.63631767], dtype=float32), array([-0.66028547], dtype=float32)) PLineL: (array([ 0.63631767], dtype=float32), array([-0.66028547], dtype=float32))
#  46%|████▌     | 115/251 [00:07<00:11, 11.44it/s]
# LineR: (array([-0.70812279], dtype=float32), array([ 884.75994873], dtype=float32)) PLineR: (array([-0.70812279], dtype=float32), array([ 884.75994873], dtype=float32))
# LineL: (array([ 0.63662547], dtype=float32), array([-0.17493528], dtype=float32)) PLineL: (array([ 0.63662547], dtype=float32), array([-0.17493528], dtype=float32))
# LineR: (array([-0.70778579], dtype=float32), array([ 885.41247559], dtype=float32)) PLineR: (array([-0.70778579], dtype=float32), array([ 885.41247559], dtype=float32))
# LineL: (array([ 0.63666129], dtype=float32), array([ 0.12972054], dtype=float32)) PLineL: (array([ 0.63666129], dtype=float32), array([ 0.12972054], dtype=float32))
# LineR: (array([-0.70775509], dtype=float32), array([ 885.68945312], dtype=float32)) PLineR: (array([-0.70775509], dtype=float32), array([ 885.68945312], dtype=float32))
# LineL: (array([ 0.63686961], dtype=float32), array([ 1.19638431], dtype=float32)) PLineL: (array([ 0.63686961], dtype=float32), array([ 1.19638431], dtype=float32))
#  47%|████▋     | 117/251 [00:07<00:12, 11.10it/s]
# LineR: (array([-0.70775133], dtype=float32), array([ 885.63311768], dtype=float32)) PLineR: (array([-0.70775133], dtype=float32), array([ 885.63311768], dtype=float32))
# LineL: (array([ 0.63696694], dtype=float32), array([ 1.59789181], dtype=float32)) PLineL: (array([ 0.63696694], dtype=float32), array([ 1.59789181], dtype=float32))
# LineR: (array([-0.70747292], dtype=float32), array([ 886.10296631], dtype=float32)) PLineR: (array([-0.70747292], dtype=float32), array([ 886.10296631], dtype=float32))
# LineL: (array([ 0.63709217], dtype=float32), array([ 2.10684752], dtype=float32)) PLineL: (array([ 0.63709217], dtype=float32), array([ 2.10684752], dtype=float32))
# LineR:
#  47%|████▋     | 119/251 [00:07<00:12, 10.77it/s]
# (array([-0.70727384], dtype=float32), array([ 885.99841309], dtype=float32)) PLineR: (array([-0.70727384], dtype=float32), array([ 885.99841309], dtype=float32))
# LineL: (array([ 0.63732725], dtype=float32), array([ 2.19119978], dtype=float32)) PLineL: (array([ 0.63732725], dtype=float32), array([ 2.19119978], dtype=float32))
# LineR: (array([-0.70704287], dtype=float32), array([ 885.88934326], dtype=float32)) PLineR: (array([-0.70704287], dtype=float32), array([ 885.88934326], dtype=float32))
# LineL: (array([ 0.63736278], dtype=float32), array([ 3.57343054], dtype=float32)) PLineL: (array([ 0.63736278], dtype=float32), array([ 3.57343054], dtype=float32))
#  48%|████▊     | 121/251 [00:07<00:12, 10.37it/s]
#
#
#
#
#  49%|████▉     | 123/251 [00:08<00:12, 10.49it/s]
# LineR: (array([-0.70706236], dtype=float32), array([ 885.9944458], dtype=float32)) PLineR: (array([-0.70706236], dtype=float32), array([ 885.9944458], dtype=float32))
# LineL: (array([ 0.6375488], dtype=float32), array([ 4.13422918], dtype=float32)) PLineL: (array([ 0.6375488], dtype=float32), array([ 4.13422918], dtype=float32))
# LineR: (array([-0.70704257], dtype=float32), array([ 886.12567139], dtype=float32)) PLineR: (array([-0.70704257], dtype=float32), array([ 886.12567139], dtype=float32))
# LineL: (array([ 0.63764912], dtype=float32), array([ 4.6243248], dtype=float32)) PLineL: (array([ 0.63764912], dtype=float32), array([ 4.6243248], dtype=float32))
# LineR: (array([-0.70709467], dtype=float32), array([ 886.3180542], dtype=float32)) PLineR: (array([-0.70709467], dtype=float32), array([ 886.3180542], dtype=float32))
# LineL: (array([ 0.63779491], dtype=float32), array([ 5.39044857], dtype=float32)) PLineL: (array([ 0.63779491], dtype=float32), array([ 5.39044857], dtype=float32))
#  50%|████▉     | 125/251 [00:08<00:11, 10.67it/s]
# LineR: (array([-0.70698082], dtype=float32), array([ 887.15124512], dtype=float32)) PLineR: (array([-0.70698082], dtype=float32), array([ 887.15124512], dtype=float32))
# LineL: (array([ 0.6378957], dtype=float32), array([ 5.29164696], dtype=float32)) PLineL: (array([ 0.6378957], dtype=float32), array([ 5.29164696], dtype=float32))
# LineR: (array([-0.70696962], dtype=float32), array([ 887.69091797], dtype=float32)) PLineR: (array([-0.70696962], dtype=float32), array([ 887.69091797], dtype=float32))
# LineL: (array([ 0.63788223], dtype=float32), array([ 6.75001383], dtype=float32)) PLineL: (array([ 0.63788223], dtype=float32), array([ 6.75001383], dtype=float32))
# LineR: (array([-0.70666683], dtype=float32), array([ 887.71154785], dtype=float32)) PLineR: (array([-0.70666683], dtype=float32), array([ 887.71154785], dtype=float32))
# LineL: (array([ 0.63784128], dtype=float32), array([ 7.3764267], dtype=float32)) PLineL: (array([ 0.63784128], dtype=float32), array([ 7.3764267], dtype=float32))
#  51%|█████     | 127/251 [00:08<00:11, 10.59it/s]
#
#
#
#
#  51%|█████▏    | 129/251 [00:08<00:11, 10.65it/s]
# LineR: (array([-0.7066589], dtype=float32), array([ 888.51031494], dtype=float32)) PLineR: (array([-0.7066589], dtype=float32), array([ 888.51031494], dtype=float32))
# LineL: (array([ 0.6379624], dtype=float32), array([ 7.73964405], dtype=float32)) PLineL: (array([ 0.6379624], dtype=float32), array([ 7.73964405], dtype=float32))
# LineR: (array([-0.70640177], dtype=float32), array([ 888.56982422], dtype=float32)) PLineR: (array([-0.70640177], dtype=float32), array([ 888.56982422], dtype=float32))
# LineL: (array([ 0.63815022], dtype=float32), array([ 9.92621326], dtype=float32)) PLineL: (array([ 0.63815022], dtype=float32), array([ 9.92621326], dtype=float32))
# LineR: (array([-0.70605063], dtype=float32), array([ 888.37475586], dtype=float32)) PLineR: (array([-0.70605063], dtype=float32), array([ 888.37475586], dtype=float32))
# LineL: (array([ 0.63854057], dtype=float32), array([ 8.97144222], dtype=float32)) PLineL: (array([ 0.63854057], dtype=float32), array([ 8.97144222], dtype=float32))
#  52%|█████▏    | 131/251 [00:08<00:11, 10.69it/s]
# LineR: (array([-0.70570052], dtype=float32), array([ 888.34698486], dtype=float32)) PLineR: (array([-0.70570052], dtype=float32), array([ 888.34698486], dtype=float32))
# LineL: (array([ 0.63868767], dtype=float32), array([ 9.58413124], dtype=float32)) PLineL: (array([ 0.63868767], dtype=float32), array([ 9.58413124], dtype=float32))
# LineR: (array([-0.70544749], dtype=float32), array([ 888.28417969], dtype=float32)) PLineR: (array([-0.70544749], dtype=float32), array([ 888.28417969], dtype=float32))
# LineL: (array([ 0.63876909], dtype=float32), array([ 10.57755947], dtype=float32)) PLineL: (array([ 0.63876909], dtype=float32), array([ 10.57755947], dtype=float32))
# LineR: (array([-0.70525187], dtype=float32), array([ 888.87463379], dtype=float32)) PLineR: (array([-0.70525187], dtype=float32), array([ 888.87463379], dtype=float32))
# LineL: (array([ 0.63875908], dtype=float32), array([ 10.58009815], dtype=float32)) PLineL: (array([ 0.63875908], dtype=float32), array([ 10.58009815], dtype=float32))
#  53%|█████▎    | 133/251 [00:08<00:11, 10.59it/s]
#
#
#
#
#  54%|█████▍    | 135/251 [00:09<00:10, 10.85it/s]
# ...
# LineR: (array([-0.6948542], dtype=float32), array([ 882.23461914], dtype=float32)) PLineR: (array([-0.6948542], dtype=float32), array([ 882.23461914], dtype=float32))
# LineL: (array([ 0.63936394], dtype=float32), array([ 9.75630093], dtype=float32)) PLineL: (array([ 0.63936394], dtype=float32), array([ 9.75630093], dtype=float32))
# LineR: (array([-0.69512904], dtype=float32), array([ 882.37390137], dtype=float32)) PLineR: (array([-0.69512904], dtype=float32), array([ 882.37390137], dtype=float32))
# LineL: (array([ 0.63933617], dtype=float32), array([ 9.69999599], dtype=float32)) PLineL: (array([ 0.63933617], dtype=float32), array([ 9.69999599], dtype=float32))
#  84%|████████▍ | 211/251 [00:13<00:02, 16.98it/s]
#
#
#
#
#  85%|████████▍ | 213/251 [00:14<00:02, 17.21it/s]
# LineR: (array([-0.6953848], dtype=float32), array([ 882.52252197], dtype=float32)) PLineR: (array([-0.6953848], dtype=float32), array([ 882.52252197], dtype=float32))
# LineL: (array([ 0.63933617], dtype=float32), array([ 9.69999599], dtype=float32)) PLineL: (array([ 0.63933617], dtype=float32), array([ 9.69999599], dtype=float32))
# LineR: (array([-0.6956054], dtype=float32), array([ 882.62530518], dtype=float32)) PLineR: (array([-0.6956054], dtype=float32), array([ 882.62530518], dtype=float32))
# LineL: (array([ 0.63924754], dtype=float32), array([ 9.68528748], dtype=float32)) PLineL: (array([ 0.63924754], dtype=float32), array([ 9.68528748], dtype=float32))
# LineR: (array([-0.69582796], dtype=float32), array([ 882.72717285], dtype=float32)) PLineR: (array([-0.69582796], dtype=float32), array([ 882.72717285], dtype=float32))
# LineL: (array([ 0.63912797], dtype=float32), array([ 9.67460155], dtype=float32)) PLineL: (array([ 0.63912797], dtype=float32), array([ 9.67460155], dtype=float32))
# LineR: (array([-0.69616663], dtype=float32), array([ 882.90588379], dtype=float32)) PLineR: (array([-0.69616663], dtype=float32), array([ 882.90588379], dtype=float32))
# LineL: (array([ 0.63912797], dtype=float32), array([ 9.67460155], dtype=float32)) PLineL: (array([ 0.63912797], dtype=float32), array([ 9.67460155], dtype=float32))
#  86%|████████▌ | 215/251 [00:14<00:02, 17.01it/s]
#
#
#
#
#  86%|████████▋ | 217/251 [00:14<00:02, 16.79it/s]
# LineR: (array([-0.6963976], dtype=float32), array([ 883.0211792], dtype=float32)) PLineR: (array([-0.6963976], dtype=float32), array([ 883.0211792], dtype=float32))
# LineL: (array([ 0.63908422], dtype=float32), array([ 9.58590889], dtype=float32)) PLineL: (array([ 0.63908422], dtype=float32), array([ 9.58590889], dtype=float32))
# LineR: (array([-0.69664413], dtype=float32), array([ 883.16705322], dtype=float32)) PLineR: (array([-0.69664413], dtype=float32), array([ 883.16705322], dtype=float32))
# LineL: (array([ 0.63900089], dtype=float32), array([ 9.52686977], dtype=float32)) PLineL: (array([ 0.63900089], dtype=float32), array([ 9.52686977], dtype=float32))
# LineR: (array([-0.696944], dtype=float32), array([ 883.34210205], dtype=float32)) PLineR: (array([-0.696944], dtype=float32), array([ 883.34210205], dtype=float32))
# LineL: (array([ 0.63901132], dtype=float32), array([ 9.41713238], dtype=float32)) PLineL: (array([ 0.63901132], dtype=float32), array([ 9.41713238], dtype=float32))
# LineR: (array([-0.69703633], dtype=float32), array([ 883.37841797], dtype=float32)) PLineR: (array([-0.69703633], dtype=float32), array([ 883.37841797], dtype=float32))
# LineL: (array([ 0.63884324], dtype=float32), array([ 9.45612907], dtype=float32)) PLineL: (array([ 0.63884324], dtype=float32), array([ 9.45612907], dtype=float32))
#  87%|████████▋ | 219/251 [00:14<00:01, 16.00it/s]
# LineR: (array([-0.69722456], dtype=float32), array([ 883.48413086], dtype=float32)) PLineR: (array([-0.69722456], dtype=float32), array([ 883.48413086], dtype=float32))
# LineL: (array([ 0.63885432], dtype=float32), array([ 9.35456944], dtype=float32)) PLineL: (array([ 0.63885432], dtype=float32), array([ 9.35456944], dtype=float32))
# LineR: (array([-0.69743145], dtype=float32), array([ 883.59289551], dtype=float32)) PLineR: (array([-0.69743145], dtype=float32), array([ 883.59289551], dtype=float32))
# LineL: (array([ 0.63882643], dtype=float32), array([ 9.28055573], dtype=float32)) PLineL: (array([ 0.63882643], dtype=float32), array([ 9.28055573], dtype=float32))
# LineR: (array([-0.69748247], dtype=float32), array([ 883.59643555], dtype=float32)) PLineR: (array([-0.69748247], dtype=float32), array([ 883.59643555], dtype=float32))
# LineL: (array([ 0.63872707], dtype=float32), array([ 9.26766014], dtype=float32)) PLineL: (array([ 0.63872707], dtype=float32), array([ 9.26766014], dtype=float32))
#  88%|████████▊ | 221/251 [00:14<00:01, 15.67it/s]
#
#
#
#
#  89%|████████▉ | 223/251 [00:14<00:01, 15.67it/s]
# LineR: (array([-0.6975258], dtype=float32), array([ 883.63677979], dtype=float32)) PLineR: (array([-0.6975258], dtype=float32), array([ 883.63677979], dtype=float32))
# LineL: (array([ 0.63877702], dtype=float32), array([ 9.13768768], dtype=float32)) PLineL: (array([ 0.63877702], dtype=float32), array([ 9.13768768], dtype=float32))
# LineR: (array([-0.69773978], dtype=float32), array([ 883.74450684], dtype=float32)) PLineR: (array([-0.69773978], dtype=float32), array([ 883.74450684], dtype=float32))
# LineL: (array([ 0.63867193], dtype=float32), array([ 9.13056469], dtype=float32)) PLineL: (array([ 0.63867193], dtype=float32), array([ 9.13056469], dtype=float32))
# LineR: (array([-0.69794232], dtype=float32), array([ 883.8427124], dtype=float32)) PLineR: (array([-0.69794232], dtype=float32), array([ 883.8427124], dtype=float32))
# LineL: (array([ 0.63867193], dtype=float32), array([ 9.13056469], dtype=float32)) PLineL: (array([ 0.63867193], dtype=float32), array([ 9.13056469], dtype=float32))
# LineR: (array([-0.69811487], dtype=float32), array([ 883.91033936], dtype=float32)) PLineR: (array([-0.69811487], dtype=float32), array([ 883.91033936], dtype=float32))
# LineL: (array([ 0.63864088], dtype=float32), array([ 9.06717587], dtype=float32)) PLineL: (array([ 0.63864088], dtype=float32), array([ 9.06717587], dtype=float32))
#  90%|████████▉ | 225/251 [00:14<00:01, 15.64it/s]
#
#
#
#
#  90%|█████████ | 227/251 [00:15<00:01, 15.63it/s]
# LineR: (array([-0.69813681], dtype=float32), array([ 883.89489746], dtype=float32)) PLineR: (array([-0.69813681], dtype=float32), array([ 883.89489746], dtype=float32))
# LineL: (array([ 0.63853163], dtype=float32), array([ 9.05322838], dtype=float32)) PLineL: (array([ 0.63853163], dtype=float32), array([ 9.05322838], dtype=float32))
# LineR: (array([-0.69830465], dtype=float32), array([ 883.980896], dtype=float32)) PLineR: (array([-0.69830465], dtype=float32), array([ 883.980896], dtype=float32))
# LineL: (array([ 0.63843614], dtype=float32), array([ 9.04538059], dtype=float32)) PLineL: (array([ 0.63843614], dtype=float32), array([ 9.04538059], dtype=float32))
# LineR: (array([-0.69853532], dtype=float32), array([ 884.10534668], dtype=float32)) PLineR: (array([-0.69853532], dtype=float32), array([ 884.10534668], dtype=float32))
# LineL: (array([ 0.63836396], dtype=float32), array([ 9.01572418], dtype=float32)) PLineL: (array([ 0.63836396], dtype=float32), array([ 9.01572418], dtype=float32))
# LineR: (array([-0.69866198], dtype=float32), array([ 884.15539551], dtype=float32)) PLineR: (array([-0.69866198], dtype=float32), array([ 884.15539551], dtype=float32))
# LineL: (array([ 0.63828069], dtype=float32), array([ 9.02138424], dtype=float32)) PLineL: (array([ 0.63828069], dtype=float32), array([ 9.02138424], dtype=float32))
#  91%|█████████ | 229/251 [00:15<00:01, 15.38it/s]
#
#
#
#
#  92%|█████████▏| 231/251 [00:15<00:01, 15.48it/s]
# LineR: (array([-0.69888347], dtype=float32), array([ 884.28283691], dtype=float32)) PLineR: (array([-0.69888347], dtype=float32), array([ 884.28283691], dtype=float32))
# LineL: (array([ 0.63828069], dtype=float32), array([ 9.02138424], dtype=float32)) PLineL: (array([ 0.63828069], dtype=float32), array([ 9.02138424], dtype=float32))
# LineR: (array([-0.69903219], dtype=float32), array([ 884.34545898], dtype=float32)) PLineR: (array([-0.69903219], dtype=float32), array([ 884.34545898], dtype=float32))
# LineL: (array([ 0.63852888], dtype=float32), array([ 8.74991703], dtype=float32)) PLineL: (array([ 0.63852888], dtype=float32), array([ 8.74991703], dtype=float32))
# LineR: (array([-0.6992805], dtype=float32), array([ 884.47869873], dtype=float32)) PLineR: (array([-0.6992805], dtype=float32), array([ 884.47869873], dtype=float32))
# LineL: (array([ 0.63852984], dtype=float32), array([ 8.67035961], dtype=float32)) PLineL: (array([ 0.63852984], dtype=float32), array([ 8.67035961], dtype=float32))
# LineR: (array([-0.69958705], dtype=float32), array([ 884.644104], dtype=float32)) PLineR: (array([-0.69958705], dtype=float32), array([ 884.644104], dtype=float32))
# LineL: (array([ 0.63860309], dtype=float32), array([ 8.54784203], dtype=float32)) PLineL: (array([ 0.63860309], dtype=float32), array([ 8.54784203], dtype=float32))
#  93%|█████████▎| 233/251 [00:15<00:01, 15.93it/s]
#
#
#
#
#  94%|█████████▎| 235/251 [00:15<00:01, 15.94it/s]
# LineR: (array([-0.69973499], dtype=float32), array([ 884.6809082], dtype=float32)) PLineR: (array([-0.69973499], dtype=float32), array([ 884.6809082], dtype=float32))
# LineL: (array([ 0.63869745], dtype=float32), array([ 8.39582443], dtype=float32)) PLineL: (array([ 0.63869745], dtype=float32), array([ 8.39582443], dtype=float32))
# LineR: (array([-0.70001858], dtype=float32), array([ 884.8369751], dtype=float32)) PLineR: (array([-0.70001858], dtype=float32), array([ 884.8369751], dtype=float32))
# LineL: (array([ 0.63866472], dtype=float32), array([ 8.34549809], dtype=float32)) PLineL: (array([ 0.63866472], dtype=float32), array([ 8.34549809], dtype=float32))
# LineR: (array([-0.70018369], dtype=float32), array([ 884.93060303], dtype=float32)) PLineR: (array([-0.70018369], dtype=float32), array([ 884.93060303], dtype=float32))
# LineL: (array([ 0.63866472], dtype=float32), array([ 8.34549809], dtype=float32)) PLineL: (array([ 0.63866472], dtype=float32), array([ 8.34549809], dtype=float32))
# LineR: (array([-0.70040661], dtype=float32), array([ 885.01556396], dtype=float32)) PLineR: (array([-0.70040661], dtype=float32), array([ 885.01556396], dtype=float32))
# LineL: (array([ 0.63866472], dtype=float32), array([ 8.34549809], dtype=float32)) PLineL: (array([ 0.63866472], dtype=float32), array([ 8.34549809], dtype=float32))
#  94%|█████████▍| 237/251 [00:15<00:00, 15.82it/s]
#
#
#
#
#  95%|█████████▌| 239/251 [00:15<00:00, 15.62it/s]
# LineR: (array([-0.70070237], dtype=float32), array([ 885.16802979], dtype=float32)) PLineR: (array([-0.70070237], dtype=float32), array([ 885.16802979], dtype=float32))
# LineL: (array([ 0.63857961], dtype=float32), array([ 8.33828926], dtype=float32)) PLineL: (array([ 0.63857961], dtype=float32), array([ 8.33828926], dtype=float32))
# LineR: (array([-0.70072031], dtype=float32), array([ 885.15594482], dtype=float32)) PLineR: (array([-0.70072031], dtype=float32), array([ 885.15594482], dtype=float32))
# LineL: (array([ 0.63853627], dtype=float32), array([ 8.26972771], dtype=float32)) PLineL: (array([ 0.63853627], dtype=float32), array([ 8.26972771], dtype=float32))
# LineR: (array([-0.70064741], dtype=float32), array([ 885.08935547], dtype=float32)) PLineR: (array([-0.70064741], dtype=float32), array([ 885.08935547], dtype=float32))
# LineL: (array([ 0.63855201], dtype=float32), array([ 8.17625618], dtype=float32)) PLineL: (array([ 0.63855201], dtype=float32), array([ 8.17625618], dtype=float32))
# LineR: (array([-0.70087463], dtype=float32), array([ 885.17541504], dtype=float32)) PLineR:
#  96%|█████████▌| 241/251 [00:15<00:00, 15.28it/s]
#  (array([-0.70087463], dtype=float32), array([ 885.17541504], dtype=float32))
# LineL: (array([ 0.63842779], dtype=float32), array([ 8.20132256], dtype=float32)) PLineL: (array([ 0.63842779], dtype=float32), array([ 8.20132256], dtype=float32))
# LineR: (array([-0.70112622], dtype=float32), array([ 885.29772949], dtype=float32)) PLineR: (array([-0.70112622], dtype=float32), array([ 885.29772949], dtype=float32))
# LineL: (array([ 0.63843721], dtype=float32), array([ 8.11142349], dtype=float32)) PLineL: (array([ 0.63843721], dtype=float32), array([ 8.11142349], dtype=float32))
# LineR: (array([-0.70119184], dtype=float32), array([ 885.32556152], dtype=float32)) PLineR: (array([-0.70119184], dtype=float32), array([ 885.32556152], dtype=float32))
# LineL: (array([ 0.63836503], dtype=float32), array([ 8.11671829], dtype=float32)) PLineL: (array([ 0.63836503], dtype=float32), array([ 8.11671829], dtype=float32))
# LineR: (array([-0.70134652], dtype=float32), array([ 885.40014648], dtype=float32)) PLineR: (array([-0.70134652], dtype=float32), array([ 885.40014648], dtype=float32))
# LineL: (array([ 0.63833016], dtype=float32), array([ 8.0860033], dtype=float32)) PLineL: (array([ 0.63833016], dtype=float32), array([ 8.0860033], dtype=float32))
#  97%|█████████▋| 243/251 [00:16<00:00, 15.46it/s]
#
#
#
#
#  98%|█████████▊| 245/251 [00:16<00:00, 15.53it/s]
# LineR: (array([-0.70143712], dtype=float32), array([ 885.42584229], dtype=float32)) PLineR: (array([-0.70143712], dtype=float32), array([ 885.42584229], dtype=float32))
# LineL: (array([ 0.63830721], dtype=float32), array([ 8.03559399], dtype=float32)) PLineL: (array([ 0.63830721], dtype=float32), array([ 8.03559399], dtype=float32))
# LineR: (array([-0.70143366], dtype=float32), array([ 885.39080811], dtype=float32)) PLineR: (array([-0.70143366], dtype=float32), array([ 885.39080811], dtype=float32))
# LineL: (array([ 0.63831973], dtype=float32), array([ 7.96464157], dtype=float32)) PLineL: (array([ 0.63831973], dtype=float32), array([ 7.96464157], dtype=float32))
# LineR: (array([-0.70150578], dtype=float32), array([ 885.40881348], dtype=float32)) PLineR: (array([-0.70150578], dtype=float32), array([ 885.40881348], dtype=float32))
# LineL: (array([ 0.63828623], dtype=float32), array([ 7.9250927], dtype=float32)) PLineL: (array([ 0.63828623], dtype=float32), array([ 7.9250927], dtype=float32))
# LineR: (array([-0.70166111], dtype=float32), array([ 885.4855957], dtype=float32)) PLineR: (array([-0.70166111], dtype=float32), array([ 885.4855957], dtype=float32))
# LineL: (array([ 0.63820195], dtype=float32), array([ 7.94641733], dtype=float32)) PLineL: (array([ 0.63820195], dtype=float32), array([ 7.94641733], dtype=float32))
#  98%|█████████▊| 247/251 [00:16<00:00, 15.49it/s]
#
#
#
#
#  99%|█████████▉| 249/251 [00:16<00:00, 15.83it/s]
#
#
#
#
# 100%|██████████| 251/251 [00:16<00:00, 16.47it/s]
# LineR: (array([-0.70182711], dtype=float32), array([ 885.56494141], dtype=float32)) PLineR: (array([-0.70182711], dtype=float32), array([ 885.56494141], dtype=float32))
# LineL: (array([ 0.6381498], dtype=float32), array([ 7.92922544], dtype=float32)) PLineL: (array([ 0.6381498], dtype=float32), array([ 7.92922544], dtype=float32))
# LineR: (array([-0.70184588], dtype=float32), array([ 885.55749512], dtype=float32)) PLineR: (array([-0.70184588], dtype=float32), array([ 885.55749512], dtype=float32))
# LineL: (array([ 0.63805491], dtype=float32), array([ 7.91692352], dtype=float32)) PLineL: (array([ 0.63805491], dtype=float32), array([ 7.91692352], dtype=float32))
# LineR: (array([-0.70202279], dtype=float32), array([ 885.63671875], dtype=float32)) PLineR: (array([-0.70202279], dtype=float32), array([ 885.63671875], dtype=float32))
# LineL: (array([ 0.63792437], dtype=float32), array([ 7.97623014], dtype=float32)) PLineL: (array([ 0.63792437], dtype=float32), array([ 7.97623014], dtype=float32))
# LineR: (array([-0.70216209], dtype=float32), array([ 885.6887207], dtype=float32)) PLineR: (array([-0.70216209], dtype=float32), array([ 885.6887207], dtype=float32))
# LineL: (array([ 0.63791752], dtype=float32), array([ 7.93450117], dtype=float32)) PLineL: (array([ 0.63791752], dtype=float32), array([ 7.93450117], dtype=float32))
# [MoviePy] Done.
# [MoviePy] >>>> Video ready: test_videos_output/challenge.mp4
#
# CPU times: user 14.1 s, sys: 4.73 s, total: 18.8 s
# Wall time: 17.7 s

# %%
HTML("""
<video width="960" height="540" controls>
  <source src="{0}">
</video>
""".format(challenge_output))
